# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\91984\Downloads\TCS_historical_data_Daily_5_Years.csv")

# %%
df
# Out:
#             Date    Open     High      Low    Close   Volume Exchange
# 0     2025-10-03  2924.0  2924.00  2891.10  2903.00  2799767      NSE
# 1     2025-10-01  2891.0  2924.80  2866.60  2916.80  1941068      NSE
# 2     2025-09-30  2911.0  2915.30  2885.10  2894.90  2228350      NSE
# 3     2025-09-29  2916.0  2929.30  2894.00  2904.30  3084635      NSE
# 4     2025-09-26  2941.0  2954.80  2891.30  2905.40  3876112      NSE
# ...          ...     ...      ...      ...      ...      ...      ...
# 1227  2020-10-23  2687.8  2702.00  2670.10  2686.80  3499372      NSE
# 1228  2020-10-22  2661.0  2686.65  2638.10  2671.15  5262311      NSE
# 1229  2020-10-21  2739.0  2749.00  2663.05  2675.40  4570175      NSE
# 1230  2020-10-20  2725.0  2759.90  2717.95  2739.00  3406298      NSE
# 1231  2020-10-19  2774.0  2774.00  2706.60  2711.55  3331194      NSE
#
# [1232 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1232 non-null   object
#  1   Open      1232 non-null   float64
#  2   High      1232 non-null   float64
#  3   Low       1232 non-null   float64
#  4   Close     1232 non-null   float64
#  5   Volume    1232 non-null   int64
#  6   Exchange  1232 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 67.5+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Exchange'], dtype='object')

# %%
# df['Date '] = pd.to_datetime(df['Date '])

# %%
df.drop(columns=['Exchange'],inplace=True)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1232.000000  1232.000000  1232.000000  1232.000000  1.232000e+03
# mean   3512.356006  3543.268709  3480.006818  3510.871510  2.429368e+06
# std     407.145359   412.034451   403.722241   407.448146  1.293514e+06
# min    2604.000000  2655.000000  2600.050000  2604.600000  6.505700e+04
# 25%    3218.125000  3243.700000  3192.000000  3215.325000  1.622162e+06
# 50%    3435.000000  3464.850000  3410.950000  3440.875000  2.084541e+06
# 75%    3810.000000  3840.312500  3772.250000  3810.950000  2.898771e+06
# max    4576.000000  4592.250000  4512.000000  4553.750000  1.350916e+07

# %%
df=df.copy(deep=True)
col=['Open', 'High', 'Low', 'Close', 'Volume']

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
for i in col:
    q25,q75=np.percentile(df[i],25),np.percentile(df[i],75)
    IQR = q75 - q25
    Threshold=IQR*1.5
    lower,upper=q25-Threshold,q75+Threshold
    outliers=[j for j in df[i] if j < lower or j > upper]
    for k in outliers:
        data_1=df.drop(df.index[df[i]==k],axis=0)

# %%
df=data_1

# %%
from sklearn.preprocessing import MinMaxScaler
features = ['Open', 'High', 'Low', 'Volume']
scalerx = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X=scalerx.fit_transform(df[features])

# %%
Y=scalery.fit_transform(df[["Close"]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,train_size=0.8,random_state=42)

# %%
df.shape
# Out:
# (1231, 5)

# %%
xtrain.shape
# Out:
# (984, 4)

# %%
xtrain = xtrain.reshape((xtrain.shape[0], 1, xtrain.shape[1]))
xtest  = xtest.reshape((xtest.shape[0], 1, xtest.shape[1]))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Bidirectional, LSTM
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt

def build_model(hp):
    model = Sequential()

    # --- CNN ---
    model.add(Conv1D(
        filters=hp.Int("filters", min_value=32, max_value=256, step=32),
        kernel_size=1,       # FIXED → only valid option for input length=1
        activation='relu',
        input_shape=(1, 4)
    ))

    model.add(MaxPooling1D(pool_size=1))

    model.add(Dropout(
        hp.Float("dropout1", 0.1, 0.5, step=0.1)
    ))

    # --- BiLSTM ---
    model.add(Bidirectional(LSTM(
        hp.Int("bilstm_units", min_value=32, max_value=128, step=32),
        return_sequences=False
    )))

    model.add(Dropout(
        hp.Float("dropout2", 0.1, 0.5, step=0.1)
    ))

    # --- Dense Layer ---
    model.add(Dense(
        hp.Int("dense_units", min_value=16, max_value=128, step=16),
        activation='relu'
    ))

    model.add(Dropout(
        hp.Float("dropout3", 0.1, 0.5, step=0.1)
    ))

    # --- Output ---
    model.add(Dense(1, activation='linear'))

    # --- Learning rate ---
    lr = hp.Float("learning_rate", 1e-4, 1e-2, sampling="log")

    model.compile(
        optimizer=Adam(lr),
        loss="mse",
        metrics=["mse", tf.keras.metrics.MeanAbsolutePercentageError(), "mae"]
    )

    return model


# -------------------------------
# TUNER
# -------------------------------
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=30,
    executions_per_trial=1,
    directory='hyper_cnn_bilstm',
    project_name='cnn_bilstm_tuning'
)


# -------------------------------
# EARLY STOPPING
# -------------------------------
max_mae = 0.005

class StopCond(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        mae = logs.get('mae')
        if mae is not None and mae < max_mae:
            print(f"✓ MAE threshold reached: {mae:.6f} < {max_mae}")
            self.model.stop_training = True

early_stop_custom = StopCond()

early_stop_general = tf.keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True
)


# -------------------------------
# RUN TUNING
# -------------------------------
tuner.search(
    xtrain, ytrain,
    epochs=50,
    validation_split=0.1,
    callbacks=[early_stop_custom, early_stop_general],
    verbose=1
)
# Out:
# Reloading Tuner from hyper_cnn_bilstm\cnn_bilstm_tuning\tuner0.json

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps.values)
# Out:
# Best Hyperparameters: {'filters': 256, 'kernel_size': 1, 'dropout1': 0.1, 'bilstm_units': 64, 'dropout2': 0.2, 'dense_units': 16, 'dropout3': 0.2, 'learning_rate': 0.001793407562581553}

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# If batch size was part of tuning:
if "batch_size" in best_hps.values:
    batch_size = best_hps.get("batch_size")
else:
    batch_size = 32   # fallback

history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs=50,
    batch_size=batch_size,
    verbose=1
)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 0.0039 - mae: 0.0426 - mean_absolute_percentage_error: 12.2271 - mse: 0.0039 - val_loss: 5.5584e-04 - val_mae: 0.0182 - val_mean_absolute_percentage_error: 193699.6562 - val_mse: 5.5584e-04
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0388 - mean_absolute_percentage_error: 12.1078 - mse: 0.0031 - val_loss: 3.8946e-04 - val_mae: 0.0160 - val_mean_absolute_percentage_error: 247728.4062 - val_mse: 3.8946e-04
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - mae: 0.0341 - mean_absolute_percentage_error: 11.4529 - mse: 0.0024 - val_loss: 2.3841e-04 - val_mae: 0.0117 - val_mean_absolute_percentage_error: 234787.2500 - val_mse: 2.3841e-04
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0026 - mae: 0.0346 - mean_absolute_percentage_error: 13.6813 - mse: 0.0026 - val_loss: 7.7167e-04 - val_mae: 0.0244 - val_mean_absolute_percentage_error: 277676.3125 - val_mse: 7.7167e-04
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0027 - mae: 0.0356 - mean_absolute_percentage_error: 11.9219 - mse: 0.0027 - val_loss: 0.0025 - val_mae: 0.0447 - val_mean_absolute_percentage_error: 179944.1562 - val_mse: 0.0025
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - mae: 0.0395 - mean_absolute_percentage_error: 12.0155 - mse: 0.0032 - val_loss: 4.7594e-04 - val_mae: 0.0177 - val_mean_absolute_percentage_error: 301327.3125 - val_mse: 4.7594e-04
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0029 - mae: 0.0366 - mean_absolute_percentage_error: 13.1025 - mse: 0.0029 - val_loss: 4.3751e-04 - val_mae: 0.0175 - val_mean_absolute_percentage_error: 195018.6406 - val_mse: 4.3751e-04
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023 - mae: 0.0326 - mean_absolute_percentage_error: 11.8356 - mse: 0.0023 - val_loss: 2.7229e-04 - val_mae: 0.0124 - val_mean_absolute_percentage_error: 260670.7344 - val_mse: 2.7229e-04
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - mae: 0.0329 - mean_absolute_percentage_error: 11.6882 - mse: 0.0023 - val_loss: 9.5163e-04 - val_mae: 0.0246 - val_mean_absolute_percentage_error: 155100.1719 - val_mse: 9.5163e-04
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0326 - mean_absolute_percentage_error: 12.9160 - mse: 0.0022 - val_loss: 2.3086e-04 - val_mae: 0.0119 - val_mean_absolute_percentage_error: 196962.9219 - val_mse: 2.3086e-04
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - mae: 0.0329 - mean_absolute_percentage_error: 12.3188 - mse: 0.0022 - val_loss: 3.2392e-04 - val_mae: 0.0138 - val_mean_absolute_percentage_error: 244153.8281 - val_mse: 3.2392e-04
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - mae: 0.0317 - mean_absolute_percentage_error: 12.7171 - mse: 0.0022 - val_loss: 2.6920e-04 - val_mae: 0.0122 - val_mean_absolute_percentage_error: 282132.2500 - val_mse: 2.6920e-04
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - mae: 0.0305 - mean_absolute_percentage_error: 14.0993 - mse: 0.0020 - val_loss: 2.8510e-04 - val_mae: 0.0135 - val_mean_absolute_percentage_error: 131378.7812 - val_mse: 2.8510e-04
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - mae: 0.0276 - mean_absolute_percentage_error: 12.1287 - mse: 0.0016 - val_loss: 2.2118e-04 - val_mae: 0.0115 - val_mean_absolute_percentage_error: 193966.6094 - val_mse: 2.2118e-04
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - mae: 0.0324 - mean_absolute_percentage_error: 12.9874 - mse: 0.0022 - val_loss: 0.0011 - val_mae: 0.0270 - val_mean_absolute_percentage_error: 297540.5625 - val_mse: 0.0011
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - mae: 0.0326 - mean_absolute_percentage_error: 16.0680 - mse: 0.0022 - val_loss: 8.0014e-04 - val_mae: 0.0240 - val_mean_absolute_percentage_error: 199846.1250 - val_mse: 8.0014e-04
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - mae: 0.0304 - mean_absolute_percentage_error: 13.8505 - mse: 0.0021 - val_loss: 2.3028e-04 - val_mae: 0.0125 - val_mean_absolute_percentage_error: 167569.7656 - val_mse: 2.3028e-04
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021 - mae: 0.0311 - mean_absolute_percentage_error: 14.1518 - mse: 0.0021 - val_loss: 2.9191e-04 - val_mae: 0.0135 - val_mean_absolute_percentage_error: 192506.3906 - val_mse: 2.9191e-04
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - mae: 0.0308 - mean_absolute_percentage_error: 13.3929 - mse: 0.0020 - val_loss: 3.1938e-04 - val_mae: 0.0147 - val_mean_absolute_percentage_error: 162423.7188 - val_mse: 3.1938e-04
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - mae: 0.0308 - mean_absolute_percentage_error: 16.3396 - mse: 0.0020 - val_loss: 4.4444e-04 - val_mae: 0.0167 - val_mean_absolute_percentage_error: 121261.9766 - val_mse: 4.4444e-04
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - mae: 0.0302 - mean_absolute_percentage_error: 12.5621 - mse: 0.0019 - val_loss: 1.5850e-04 - val_mae: 0.0098 - val_mean_absolute_percentage_error: 135289.7031 - val_mse: 1.5850e-04
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - mae: 0.0332 - mean_absolute_percentage_error: 14.8946 - mse: 0.0021 - val_loss: 6.1791e-04 - val_mae: 0.0207 - val_mean_absolute_percentage_error: 337638.1875 - val_mse: 6.1791e-04
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0020 - mae: 0.0305 - mean_absolute_percentage_error: 13.0195 - mse: 0.0020 - val_loss: 4.2122e-04 - val_mae: 0.0153 - val_mean_absolute_percentage_error: 321945.7188 - val_mse: 4.2122e-04
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - mae: 0.0294 - mean_absolute_percentage_error: 13.2570 - mse: 0.0018 - val_loss: 4.0670e-04 - val_mae: 0.0172 - val_mean_absolute_percentage_error: 215473.9531 - val_mse: 4.0670e-04
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0018 - mae: 0.0290 - mean_absolute_percentage_error: 14.3801 - mse: 0.0018 - val_loss: 2.7263e-04 - val_mae: 0.0127 - val_mean_absolute_percentage_error: 251060.1250 - val_mse: 2.7263e-04
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mae: 0.0316 - mean_absolute_percentage_error: 13.4058 - mse: 0.0020 - val_loss: 5.2648e-04 - val_mae: 0.0190 - val_mean_absolute_percentage_error: 165753.6250 - val_mse: 5.2648e-04
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0020 - mae: 0.0306 - mean_absolute_percentage_error: 12.3960 - mse: 0.0020 - val_loss: 4.7239e-04 - val_mae: 0.0179 - val_mean_absolute_percentage_error: 209759.2500 - val_mse: 4.7239e-04
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - mae: 0.0297 - mean_absolute_percentage_error: 13.7735 - mse: 0.0021 - val_loss: 4.5848e-04 - val_mae: 0.0176 - val_mean_absolute_percentage_error: 262518.7500 - val_mse: 4.5848e-04
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - mae: 0.0312 - mean_absolute_percentage_error: 13.3144 - mse: 0.0021 - val_loss: 0.0011 - val_mae: 0.0289 - val_mean_absolute_percentage_error: 93222.6094 - val_mse: 0.0011
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0018 - mae: 0.0295 - mean_absolute_percentage_error: 12.1735 - mse: 0.0018 - val_loss: 3.7859e-04 - val_mae: 0.0146 - val_mean_absolute_percentage_error: 247770.6250 - val_mse: 3.7859e-04
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017 - mae: 0.0288 - mean_absolute_percentage_error: 12.5305 - mse: 0.0017 - val_loss: 2.7351e-04 - val_mae: 0.0132 - val_mean_absolute_percentage_error: 156772.8906 - val_mse: 2.7351e-04
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - mae: 0.0307 - mean_absolute_percentage_error: 14.0735 - mse: 0.0020 - val_loss: 3.8458e-04 - val_mae: 0.0168 - val_mean_absolute_percentage_error: 223784.6094 - val_mse: 3.8458e-04
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0021 - mae: 0.0323 - mean_absolute_percentage_error: 12.9055 - mse: 0.0021 - val_loss: 2.6240e-04 - val_mae: 0.0132 - val_mean_absolute_percentage_error: 253225.4844 - val_mse: 2.6240e-04
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - mae: 0.0291 - mean_absolute_percentage_error: 10.8616 - mse: 0.0019 - val_loss: 1.9724e-04 - val_mae: 0.0105 - val_mean_absolute_percentage_error: 240528.5781 - val_mse: 1.9724e-04
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - mae: 0.0304 - mean_absolute_percentage_error: 13.2240 - mse: 0.0020 - val_loss: 3.4596e-04 - val_mae: 0.0146 - val_mean_absolute_percentage_error: 180136.9375 - val_mse: 3.4596e-04
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - mae: 0.0295 - mean_absolute_percentage_error: 14.0118 - mse: 0.0019 - val_loss: 4.2006e-04 - val_mae: 0.0174 - val_mean_absolute_percentage_error: 238505.6875 - val_mse: 4.2006e-04
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - mae: 0.0296 - mean_absolute_percentage_error: 13.1426 - mse: 0.0019 - val_loss: 8.0296e-04 - val_mae: 0.0240 - val_mean_absolute_percentage_error: 271920.3750 - val_mse: 8.0296e-04
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - mae: 0.0307 - mean_absolute_percentage_error: 14.8608 - mse: 0.0020 - val_loss: 2.7949e-04 - val_mae: 0.0130 - val_mean_absolute_percentage_error: 94982.8047 - val_mse: 2.7949e-04
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - mae: 0.0301 - mean_absolute_percentage_error: 14.3749 - mse: 0.0018 - val_loss: 2.1227e-04 - val_mae: 0.0118 - val_mean_absolute_percentage_error: 150070.4844 - val_mse: 2.1227e-04
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0297 - mean_absolute_percentage_error: 11.1669 - mse: 0.0018 - val_loss: 4.9323e-04 - val_mae: 0.0165 - val_mean_absolute_percentage_error: 347895.6250 - val_mse: 4.9323e-04
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0334 - mean_absolute_percentage_error: 16.0846 - mse: 0.0024 - val_loss: 5.5010e-04 - val_mae: 0.0207 - val_mean_absolute_percentage_error: 208434.0781 - val_mse: 5.5010e-04
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - mae: 0.0294 - mean_absolute_percentage_error: 13.9209 - mse: 0.0017 - val_loss: 3.5373e-04 - val_mae: 0.0140 - val_mean_absolute_percentage_error: 339230.9062 - val_mse: 3.5373e-04
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - mae: 0.0301 - mean_absolute_percentage_error: 16.0884 - mse: 0.0020 - val_loss: 1.9853e-04 - val_mae: 0.0109 - val_mean_absolute_percentage_error: 135811.6562 - val_mse: 1.9853e-04
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - mae: 0.0294 - mean_absolute_percentage_error: 12.2190 - mse: 0.0018 - val_loss: 3.6873e-04 - val_mae: 0.0154 - val_mean_absolute_percentage_error: 242940.6875 - val_mse: 3.6873e-04
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - mae: 0.0287 - mean_absolute_percentage_error: 12.3996 - mse: 0.0018 - val_loss: 1.7736e-04 - val_mae: 0.0098 - val_mean_absolute_percentage_error: 235368.8594 - val_mse: 1.7736e-04
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - mae: 0.0301 - mean_absolute_percentage_error: 13.0985 - mse: 0.0019 - val_loss: 9.0918e-04 - val_mae: 0.0250 - val_mean_absolute_percentage_error: 183377.8906 - val_mse: 9.0918e-04
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - mae: 0.0281 - mean_absolute_percentage_error: 15.6913 - mse: 0.0017 - val_loss: 4.5824e-04 - val_mae: 0.0177 - val_mean_absolute_percentage_error: 212180.4688 - val_mse: 4.5824e-04
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - mae: 0.0304 - mean_absolute_percentage_error: 13.6613 - mse: 0.0021 - val_loss: 2.6162e-04 - val_mae: 0.0122 - val_mean_absolute_percentage_error: 258976.5156 - val_mse: 2.6162e-04
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - mae: 0.0307 - mean_absolute_percentage_error: 14.2280 - mse: 0.0020 - val_loss: 2.1425e-04 - val_mae: 0.0115 - val_mean_absolute_percentage_error: 159734.1250 - val_mse: 2.1425e-04
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - mae: 0.0303 - mean_absolute_percentage_error: 13.8651 - mse: 0.0020 - val_loss: 2.4594e-04 - val_mae: 0.0123 - val_mean_absolute_percentage_error: 230814.4219 - val_mse: 2.4594e-04

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print("x test shape:", xtest.shape)

# Directly predict (no reshape needed)
y_pred1 = best_model.predict(xtest)
y_pred1 = y_pred1.flatten()

r2 = r2_score(ytest, y_pred1)

print(f" r2 : {r2:.4f}")
# Out:
# x test shape: (247, 1, 4)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#  r2 : 0.9946

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)

plt.title('Model Loss Curve', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(ytest,y_pred1,alpha=0.6,color="royalblue",edgecolor='k')

min_val=min(min(ytest),min(y_pred1))
max_val = max(max(ytest),max(y_pred1))

plt.plot([min_val,max_val],[min_val,max_val],color='red',linestyle='--',linewidth=2)
plt.title('Actual vs Predicted Values', fontsize=14)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [raw]
# use seperate scaler

# %%
y_pred_reshaped = y_pred1.reshape(-1, 1)
y_pred_actual = scalery.inverse_transform(y_pred_reshaped)

# %% [markdown]
# Hence,LSTM is the best one for the prediction

# %% [markdown]
# input values are "OPEN ","HIGH ","LOW ","PREV. CLOSE ","ltp ","52W H ","52W L ","VOLUME ","No of trades "

# %% [raw]
# op=float(input("Enter the open price:"))
# hi=float(input("Enter the High price in that time:"))
# lo=float(input("Enter the Low price in that time:"))
# pre=float(input("Enter the PREV.CLOSE:"))
# ltp=float(input("Enter the Real-time current price:"))
# fih=float(input("Enter the 52-week highest price:"))
# lih=float(input("Enter the 52-week lowest price:"))
# vol=int(input("Enter the volume:"))
# trad=int(input("Enter the Number of shares traded :"))

# %% [raw]
# def prediction(op,hi,lo,pre,ltp,fih,lih,vol,trad):
#     value =[[op,hi,lo,pre,ltp,fih,lih,vol,trad]]
#     value_1 = pd.DataFrame(value)
#     val = scalerx.fit_transform(value_1)
#     values = np.reshape(val, (val.shape[0], 1, val.shape[1]))
#     predict = model_lstm.predict(values)
#     return predict

# %% [raw]
# predict = prediction(op, hi, lo, pre, ltp, fih, lih, vol, trad)

# %% [raw]
# ypred = predict.reshape(-1, 1)
# y = scalery.inverse_transform(ypred)

# %% [raw]
# y

# %%
data = pd.read_csv(r"C:\Users\91984\Downloads\Quote-Equity-TCS-EQ-15-09-2025-to-15-10-2025.csv")

# %%
data
# Out:
#           Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0   15-Oct-2025      EQ  2,971.00  2,979.70  2,951.00     2,960.30  2,970.00
# 1   14-Oct-2025      EQ  3,021.00  3,027.20  2,955.50     3,007.20  2,960.00
# 2   13-Oct-2025      EQ  3,027.00  3,035.50  2,998.20     3,028.30  3,006.00
# 3   10-Oct-2025      EQ  3,050.00  3,070.00  3,006.90     3,061.70  3,028.00
# 4   09-Oct-2025      EQ  3,034.00  3,066.00  3,020.00     3,027.20  3,060.20
# 5   08-Oct-2025      EQ  2,975.00  3,043.00  2,968.00     2,973.70  3,031.50
# 6   07-Oct-2025      EQ  2,995.00  3,004.50  2,955.50     2,988.40  2,975.00
# 7   06-Oct-2025      EQ  2,902.00  2,993.60  2,895.60     2,901.90  2,988.00
# 8   03-Oct-2025      EQ  2,924.00  2,924.00  2,891.10     2,914.20  2,903.00
# 9   01-Oct-2025      EQ  2,891.00  2,924.80  2,866.60     2,888.40  2,915.10
# 10  30-Sep-2025      EQ  2,911.00  2,915.30  2,885.10     2,896.10  2,891.00
# 11  29-Sep-2025      EQ  2,916.00  2,929.30  2,894.00     2,899.10  2,904.30
# 12  26-Sep-2025      EQ  2,941.00  2,954.80  2,891.30     2,957.40  2,905.40
# 13  25-Sep-2025      EQ  3,022.00  3,029.60  2,951.00     3,035.40  2,958.00
# 14  24-Sep-2025      EQ  3,050.00  3,057.00  3,033.00     3,062.40  3,036.80
# 15  23-Sep-2025      EQ  3,070.00  3,080.70  3,052.00     3,073.80  3,065.00
# 16  22-Sep-2025      EQ  3,095.00  3,106.90  3,065.00     3,169.20  3,075.50
# 17  19-Sep-2025      EQ  3,170.00  3,180.50  3,144.00     3,176.70  3,171.00
# 18  18-Sep-2025      EQ  3,185.00  3,203.00  3,161.40     3,172.80  3,177.00
# 19  17-Sep-2025      EQ  3,152.00  3,182.40  3,142.40     3,145.70  3,175.00
# 20  16-Sep-2025      EQ  3,128.00  3,150.00  3,109.10     3,111.90  3,147.90
# 21  15-Sep-2025      EQ  3,134.00  3,134.00  3,096.00     3,133.40  3,112.50
#
#       close      vwap     52W H     52W L     VOLUME               VALUE   \
# 0   2,969.80  2,967.01  4,494.90  2,866.60  42,82,226  12,70,53,86,117.20
# 1   2,960.30  2,976.34  4,494.90  2,866.60  36,11,416  10,74,87,94,587.50
# 2   3,007.20  3,011.37  4,494.90  2,866.60  28,66,865   8,63,31,80,149.10
# 3   3,028.30  3,032.16  4,494.90  2,866.60  88,17,365  26,73,56,29,672.60
# 4   3,061.70  3,046.36  4,494.90  2,866.60  32,11,304   9,78,27,98,225.60
# 5   3,027.20  3,024.78  4,494.90  2,866.60  41,21,889  12,46,78,11,108.50
# 6   2,973.70  2,971.70  4,494.90  2,866.60  30,62,943   9,10,21,39,525.60
# 7   2,988.40  2,959.88  4,494.90  2,866.60  21,12,774   6,25,35,56,716.30
# 8   2,901.90  2,902.27  4,494.90  2,866.60  28,99,519   8,41,51,75,156.20
# 9   2,914.20  2,897.26  4,494.90  2,866.60  19,52,902   5,65,80,70,903.00
# 10  2,888.40  2,895.89  4,494.90  2,885.10  22,53,458   6,52,57,55,380.40
# 11  2,896.10  2,904.37  4,494.90  2,891.30  31,10,035   9,03,26,90,025.70
# 12  2,899.10  2,915.19  4,494.90  2,891.30  39,34,636  11,47,02,04,570.00
# 13  2,957.40  2,977.56  4,494.90  2,951.00  49,74,361  14,81,14,52,426.90
# 14  3,035.40  3,044.04  4,494.90  2,991.60  16,25,714   4,94,87,46,206.60
# 15  3,062.40  3,063.85  4,494.90  2,991.60  31,77,741   9,73,61,21,756.20
# 16  3,073.80  3,082.86  4,494.90  2,991.60  36,34,901  11,20,58,89,441.10
# 17  3,169.20  3,163.36  4,546.05  2,991.60  49,01,694  15,50,58,26,514.10
# 18  3,176.70  3,179.00  4,546.05  2,991.60  26,33,138   8,37,07,38,058.40
# 19  3,172.80  3,170.19  4,546.05  2,991.60  24,18,271   7,66,63,88,043.20
# 20  3,145.70  3,132.70  4,546.05  2,991.60  25,73,429   8,06,17,82,019.30
# 21  3,111.90  3,108.20  4,546.05  2,991.60  17,32,539   5,38,50,83,002.30
#
#    No of trades
# 0       1,46,773
# 1       1,83,673
# 2       1,69,572
# 3       2,44,153
# 4       1,33,703
# 5       1,54,336
# 6       1,41,987
# 7       1,00,920
# 8       1,56,466
# 9       1,24,217
# 10      2,01,510
# 11      1,79,197
# 12      3,90,339
# 13      4,18,858
# 14      1,01,133
# 15      1,41,198
# 16      3,21,272
# 17      1,09,280
# 18      1,47,801
# 19      1,00,973
# 20        96,675
# 21      1,45,801

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           22 non-null     object
#  1   series         22 non-null     object
#  2   OPEN           22 non-null     object
#  3   HIGH           22 non-null     object
#  4   LOW            22 non-null     object
#  5   PREV. CLOSE    22 non-null     object
#  6   ltp            22 non-null     object
#  7   close          22 non-null     object
#  8   vwap           22 non-null     object
#  9   52W H          22 non-null     object
#  10  52W L          22 non-null     object
#  11  VOLUME         22 non-null     object
#  12  VALUE          22 non-null     object
#  13  No of trades   22 non-null     object
# dtypes: object(14)
# memory usage: 2.5+ KB

# %%
numeric_columns = ["OPEN ","HIGH ","LOW ","PREV. CLOSE ","close ","ltp ","52W H ","52W L ","VOLUME ","No of trades "]

# %%
for i in numeric_columns:
    data[i]=data[i].str.replace(',','')
    data[i]=pd.to_numeric(data[i],errors='coerce')

# %%
data.drop(columns=['VALUE ','vwap ',"series ","PREV. CLOSE ","ltp ","52W H ","52W L ","No of trades "],inplace=True)

# %%
data['Date '] = pd.to_datetime(data['Date '])
data.set_index('Date ', inplace=True)

# %%
data
# Out:
#              OPEN    HIGH     LOW   close   VOLUME
# Date
# 2025-10-15  2971.0  2979.7  2951.0  2969.8  4282226
# 2025-10-14  3021.0  3027.2  2955.5  2960.3  3611416
# 2025-10-13  3027.0  3035.5  2998.2  3007.2  2866865
# 2025-10-10  3050.0  3070.0  3006.9  3028.3  8817365
# 2025-10-09  3034.0  3066.0  3020.0  3061.7  3211304
# 2025-10-08  2975.0  3043.0  2968.0  3027.2  4121889
# 2025-10-07  2995.0  3004.5  2955.5  2973.7  3062943
# 2025-10-06  2902.0  2993.6  2895.6  2988.4  2112774
# 2025-10-03  2924.0  2924.0  2891.1  2901.9  2899519
# 2025-10-01  2891.0  2924.8  2866.6  2914.2  1952902
# 2025-09-30  2911.0  2915.3  2885.1  2888.4  2253458
# 2025-09-29  2916.0  2929.3  2894.0  2896.1  3110035
# 2025-09-26  2941.0  2954.8  2891.3  2899.1  3934636
# 2025-09-25  3022.0  3029.6  2951.0  2957.4  4974361
# 2025-09-24  3050.0  3057.0  3033.0  3035.4  1625714
# 2025-09-23  3070.0  3080.7  3052.0  3062.4  3177741
# 2025-09-22  3095.0  3106.9  3065.0  3073.8  3634901
# 2025-09-19  3170.0  3180.5  3144.0  3169.2  4901694
# 2025-09-18  3185.0  3203.0  3161.4  3176.7  2633138
# 2025-09-17  3152.0  3182.4  3142.4  3172.8  2418271
# 2025-09-16  3128.0  3150.0  3109.1  3145.7  2573429
# 2025-09-15  3134.0  3134.0  3096.0  3111.9  1732539

# %% [raw]
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume'
#  ["OPEN ","HIGH ","LOW ","PREV. CLOSE ","ltp ","52W H ","52W L ","VOLUME ","No of trades "]

# %%
data = data.rename(columns={"Date ":"Date","OPEN ":"Open","HIGH ":'High',"LOW ":'Low','close ':"Close","VOLUME ":'Volume'})

# %%
data["Close"]
# Out:
# Date
# 2025-10-15    2969.8
# 2025-10-14    2960.3
# 2025-10-13    3007.2
# 2025-10-10    3028.3
# 2025-10-09    3061.7
# 2025-10-08    3027.2
# 2025-10-07    2973.7
# 2025-10-06    2988.4
# 2025-10-03    2901.9
# 2025-10-01    2914.2
# 2025-09-30    2888.4
# 2025-09-29    2896.1
# 2025-09-26    2899.1
# 2025-09-25    2957.4
# 2025-09-24    3035.4
# 2025-09-23    3062.4
# 2025-09-22    3073.8
# 2025-09-19    3169.2
# 2025-09-18    3176.7
# 2025-09-17    3172.8
# 2025-09-16    3145.7
# 2025-09-15    3111.9
# Name: Close, dtype: float64

# %%
X1=data.drop(columns ="Close")
value = scalerx.transform(X1)
value = np.reshape(value, (value.shape[0], 1, value.shape[1]))
predict1 = best_model.predict(value)
predict1 = np.array(predict1).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step

# %%
y1 = predict1.reshape(-1, 1)
y1 = scalery.inverse_transform(y1)

# %%
y1
# Out:
# array([[2992.1418],
#        [3023.2676],
#        [3045.509 ],
#        [3085.3098],
#        [3066.8418],
#        [3029.912 ],
#        [3012.217 ],
#        [2981.3767],
#        [2947.3606],
#        [2940.7808],
#        [2943.257 ],
#        [2948.814 ],
#        [2958.6438],
#        [3022.1892],
#        [3075.0337],
#        [3089.05  ],
#        [3108.2615],
#        [3182.1055],
#        [3196.9553],
#        [3178.59  ],
#        [3150.595 ],
#        [3141.6272]], dtype=float32)

# %%
data
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2025-10-15  2971.0  2979.7  2951.0  2969.8  4282226
# 2025-10-14  3021.0  3027.2  2955.5  2960.3  3611416
# 2025-10-13  3027.0  3035.5  2998.2  3007.2  2866865
# 2025-10-10  3050.0  3070.0  3006.9  3028.3  8817365
# 2025-10-09  3034.0  3066.0  3020.0  3061.7  3211304
# 2025-10-08  2975.0  3043.0  2968.0  3027.2  4121889
# 2025-10-07  2995.0  3004.5  2955.5  2973.7  3062943
# 2025-10-06  2902.0  2993.6  2895.6  2988.4  2112774
# 2025-10-03  2924.0  2924.0  2891.1  2901.9  2899519
# 2025-10-01  2891.0  2924.8  2866.6  2914.2  1952902
# 2025-09-30  2911.0  2915.3  2885.1  2888.4  2253458
# 2025-09-29  2916.0  2929.3  2894.0  2896.1  3110035
# 2025-09-26  2941.0  2954.8  2891.3  2899.1  3934636
# 2025-09-25  3022.0  3029.6  2951.0  2957.4  4974361
# 2025-09-24  3050.0  3057.0  3033.0  3035.4  1625714
# 2025-09-23  3070.0  3080.7  3052.0  3062.4  3177741
# 2025-09-22  3095.0  3106.9  3065.0  3073.8  3634901
# 2025-09-19  3170.0  3180.5  3144.0  3169.2  4901694
# 2025-09-18  3185.0  3203.0  3161.4  3176.7  2633138
# 2025-09-17  3152.0  3182.4  3142.4  3172.8  2418271
# 2025-09-16  3128.0  3150.0  3109.1  3145.7  2573429
# 2025-09-15  3134.0  3134.0  3096.0  3111.9  1732539

# %%
y2=data["Close"].values.reshape(-1, 1)

# %%
y2
# Out:
# array([[2969.8],
#        [2960.3],
#        [3007.2],
#        [3028.3],
#        [3061.7],
#        [3027.2],
#        [2973.7],
#        [2988.4],
#        [2901.9],
#        [2914.2],
#        [2888.4],
#        [2896.1],
#        [2899.1],
#        [2957.4],
#        [3035.4],
#        [3062.4],
#        [3073.8],
#        [3169.2],
#        [3176.7],
#        [3172.8],
#        [3145.7],
#        [3111.9]])

# %%
r2 = r2_score(y1, y2)

print(f" r2 : {r2:.4f}")
# Out:
#  r2 : 0.7790

# %%
plt.figure(figsize=(10,4))
plt.plot(y2,label="acutual value",linewidth=2)
plt.plot(y1,label="predicted value",linewidth=2)
plt.title("Actualvs prediction value of one month",fontsize=22)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
