# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\91984\Downloads\TCS_historical_data_Daily_10_Years.csv")

# %%
df1 = pd.read_csv(r"C:\Users\91984\Downloads\TCS_historical_data_Daily_Full_History.csv")

# %%
df
# Out:
#             Date     Open     High      Low    Close   Volume Exchange
# 0     2025-10-03  2924.00  2924.00  2891.10  2903.00  2799767      NSE
# 1     2025-10-01  2891.00  2924.80  2866.60  2916.80  1941068      NSE
# 2     2025-09-30  2911.00  2915.30  2885.10  2894.90  2228350      NSE
# 3     2025-09-29  2916.00  2929.30  2894.00  2904.30  3084635      NSE
# 4     2025-09-26  2941.00  2954.80  2891.30  2905.40  3876112      NSE
# ...          ...      ...      ...      ...      ...      ...      ...
# 2458  2015-10-28  1255.03  1266.78  1255.03  1264.55  1255342      NSE
# 2459  2015-10-27  1265.03  1272.45  1260.18  1265.55  1530420      NSE
# 2460  2015-10-26  1274.50  1274.50  1257.55  1268.28  1414630      NSE
# 2461  2015-10-23  1274.00  1274.00  1263.65  1268.58  2335398      NSE
# 2462  2015-10-21  1267.50  1271.00  1261.13  1265.00  1929688      NSE
#
# [2463 rows x 7 columns]

# %%
df1
# Out:
#             Date     Open     High      Low    Close     Volume Exchange
# 0     2025-09-23  3070.00  3080.70  3052.00  3065.00    3055485      NSE
# 1     2025-09-22  3095.00  3106.90  3065.00  3075.50    2914607      NSE
# 2     2025-09-19  3170.00  3180.50  3144.00  3171.00    4883224      NSE
# 3     2025-09-18  3185.00  3203.00  3161.40  3177.00    2613572      NSE
# 4     2025-09-17  3152.00  3182.40  3142.40  3175.00    2409180      NSE
# ...          ...      ...      ...      ...      ...        ...      ...
# 5207  2004-08-31   121.42   121.85   120.13   121.62   21194656      NSE
# 5208  2004-08-30   119.38   121.85   118.78   121.45   24465208      NSE
# 5209  2004-08-27   120.92   120.92   117.98   118.49   30646000      NSE
# 5210  2004-08-26   122.10   122.71   120.04   120.50   40443200      NSE
# 5211  2004-08-25   147.54   147.54   120.50   121.60  136930976      NSE
#
# [5212 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2463 non-null   object
#  1   Open      2463 non-null   float64
#  2   High      2463 non-null   float64
#  3   Low       2463 non-null   float64
#  4   Close     2463 non-null   float64
#  5   Volume    2463 non-null   int64
#  6   Exchange  2463 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 134.8+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Exchange'], dtype='object')

# %%
# df['Date '] = pd.to_datetime(df['Date '])

# %%
df.drop(columns=['Exchange'],inplace=True)

# %%
df1.drop(columns=['Exchange'],inplace=True)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  2463.000000  2463.000000  2463.000000  2463.000000  2.463000e+03
# mean   2585.905826  2610.474693  2560.201230  2584.980832  2.678150e+06
# std    1018.061389  1025.963757  1009.972351  1017.444424  2.388465e+06
# min    1058.450000  1070.000000  1025.950000  1050.580000  6.505700e+04
# 25%    1606.915000  1698.315000  1578.240000  1645.275000  1.650828e+06
# 50%    2661.000000  2689.000000  2627.550000  2660.250000  2.238097e+06
# 75%    3435.000000  3464.850000  3410.950000  3440.875000  3.089852e+06
# max    4576.000000  4592.250000  4512.000000  4553.750000  8.806715e+07

# %%
df=df.copy(deep=True)
col=['Open', 'High', 'Low', 'Close', 'Volume']

# %%
df=df1.copy(deep=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1.set_index('Date', inplace=True)

# %%
for i in col:
    q25,q75=np.percentile(df[i],25),np.percentile(df[i],75)
    IQR = q75 - q25
    Threshold=IQR*1.5
    lower,upper=q25-Threshold,q75+Threshold
    outliers=[j for j in df[i] if j < lower or j > upper]
    for k in outliers:
        df=df.drop(df.index[df[i]==k],axis=0)

# %%
for i in col:
    q25,q75=np.percentile(df1[i],25),np.percentile(df1[i],75)
    IQR = q75 - q25
    Threshold=IQR*1.5
    lower,upper=q25-Threshold,q75+Threshold
    outliers=[j for j in df1[i] if j < lower or j > upper]
    for k in outliers:
        df1=df1.drop(df1.index[df1[i]==k],axis=0)

# %%
from sklearn.preprocessing import MinMaxScaler
features = ['Open', 'High', 'Low', 'Volume']
scalerx = MinMaxScaler()
scalery = MinMaxScaler()

# %%
scalerx1 = MinMaxScaler()
scalery1 = MinMaxScaler()

# %%
X=scalerx.fit_transform(df[features])

# %%
X1=scalerx1.fit_transform(df1[features])

# %%
Y=scalery.fit_transform(df[["Close"]])

# %%
Y1=scalery1.fit_transform(df1[["Close"]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,train_size=0.8,random_state=42)

# %%
xtrain = np.reshape(xtrain, (xtrain.shape[0],1, xtrain.shape[1]))
xtest = xtest.reshape((xtest.shape[0], 1, xtest.shape[1]))

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_lstm_model(hp):

    model = Sequential()

    # Tune number of LSTM layers (1–3)
    for i in range(hp.Int("num_lstm_layers", 1, 3)):
        model.add(
            LSTM(
                units=hp.Int(f"lstm_units_{i}", 32, 256, step=32),
                return_sequences=(i < hp.get("num_lstm_layers") - 1)
            )
        )
        model.add(Dropout(
            hp.Float(f"dropout_{i}", 0.1, 0.5, step=0.1)
        ))

    # Dense layer tuning
    model.add(Dense(
        units=hp.Int("dense_units", 16, 128, step=16),
        activation="relu"
    ))

    # Output layer
    model.add(Dense(1))

    # Learning rate tuning
    lr = hp.Choice("learning_rate", [1e-2, 1e-3, 5e-4, 1e-4])

    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss="mean_squared_error",
        metrics=["mse"]
    )

    return model

# %%
tuner = kt.BayesianOptimization(
    build_lstm_model,
    objective="val_loss",
    max_trials=25,
    directory="lstm_bayesian_tuning",
    project_name="tcs_lstm"
)

tuner.search_space_summary()
# Out:
# Reloading Tuner from lstm_bayesian_tuning\tcs_lstm\tuner0.json
# Search space summary
# Default search space size: 9
# num_lstm_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': 'linear'}
# lstm_units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_0 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# dense_units (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0005, 0.0001], 'ordered': True}
# lstm_units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_1 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# lstm_units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_2 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}

# %%
tuner.search(
    xtrain, ytrain,
    epochs=15,
    validation_data=(xtest, ytest),
    verbose=1
)

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps.values)
# Out:
# Best Hyperparameters: {'num_lstm_layers': 2, 'lstm_units_0': 96, 'dropout_0': 0.30000000000000004, 'dense_units': 32, 'learning_rate': 0.01, 'lstm_units_1': 128, 'dropout_1': 0.1, 'lstm_units_2': 64, 'dropout_2': 0.4}

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# If batch size was part of tuning:
if "batch_size" in best_hps.values:
    batch_size = best_hps.get("batch_size")
else:
    batch_size = 32   # fallback

history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs=50,
    batch_size=batch_size,
    verbose=1
)
# Out:
# WARNING:tensorflow:From C:\Users\91984\Desktop\project\my_venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 3.2658e-04 - val_mse: 3.2658e-04
# Epoch 2/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 7.9411e-04 - mse: 7.9411e-04 - val_loss: 3.1786e-04 - val_mse: 3.1786e-04
# Epoch 3/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 7.3508e-04 - mse: 7.3508e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 4/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 2.4143e-04 - val_mse: 2.4143e-04
# Epoch 5/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 7.9198e-04 - mse: 7.9198e-04 - val_loss: 7.3846e-05 - val_mse: 7.3846e-05
# Epoch 6/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 6.6515e-04 - mse: 6.6515e-04 - val_loss: 1.5364e-04 - val_mse: 1.5364e-04
# Epoch 7/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.7088e-04 - mse: 4.7088e-04 - val_loss: 1.3680e-04 - val_mse: 1.3680e-04
# Epoch 8/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 4.7754e-04 - mse: 4.7754e-04 - val_loss: 5.5199e-04 - val_mse: 5.5199e-04
# Epoch 9/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 4.9071e-04 - mse: 4.9071e-04 - val_loss: 1.9169e-04 - val_mse: 1.9169e-04
# Epoch 10/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 3.5926e-04 - mse: 3.5926e-04 - val_loss: 6.2904e-05 - val_mse: 6.2904e-05
# Epoch 11/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.8793e-04 - mse: 4.8793e-04 - val_loss: 5.4277e-04 - val_mse: 5.4277e-04
# Epoch 12/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.6950e-04 - mse: 3.6950e-04 - val_loss: 1.9281e-04 - val_mse: 1.9281e-04
# Epoch 13/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 3.6802e-04 - mse: 3.6802e-04 - val_loss: 1.1165e-04 - val_mse: 1.1165e-04
# Epoch 14/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 4.6191e-04 - mse: 4.6191e-04 - val_loss: 2.3007e-04 - val_mse: 2.3007e-04
# Epoch 15/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 3.6958e-04 - mse: 3.6958e-04 - val_loss: 1.7799e-04 - val_mse: 1.7799e-04
# Epoch 16/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 3.8758e-04 - mse: 3.8758e-04 - val_loss: 3.3097e-04 - val_mse: 3.3097e-04
# Epoch 17/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 3.6225e-04 - mse: 3.6225e-04 - val_loss: 8.4287e-05 - val_mse: 8.4287e-05
# Epoch 18/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.8759e-04 - mse: 2.8759e-04 - val_loss: 1.0256e-04 - val_mse: 1.0256e-04
# Epoch 19/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 3.4880e-04 - mse: 3.4880e-04 - val_loss: 3.9777e-04 - val_mse: 3.9777e-04
# Epoch 20/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 3.0652e-04 - mse: 3.0652e-04 - val_loss: 2.0291e-04 - val_mse: 2.0291e-04
# Epoch 21/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.8142e-04 - mse: 3.8142e-04 - val_loss: 4.7650e-04 - val_mse: 4.7650e-04
# Epoch 22/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 3.6012e-04 - mse: 3.6012e-04 - val_loss: 9.3947e-05 - val_mse: 9.3947e-05
# Epoch 23/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.4127e-04 - mse: 2.4127e-04 - val_loss: 2.8559e-04 - val_mse: 2.8559e-04
# Epoch 24/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.4090e-04 - mse: 4.4090e-04 - val_loss: 1.1819e-04 - val_mse: 1.1819e-04
# Epoch 25/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.5782e-04 - mse: 2.5782e-04 - val_loss: 4.3434e-05 - val_mse: 4.3434e-05
# Epoch 26/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.7739e-04 - mse: 2.7739e-04 - val_loss: 3.2798e-04 - val_mse: 3.2798e-04
# Epoch 27/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.3122e-04 - mse: 2.3122e-04 - val_loss: 1.3022e-04 - val_mse: 1.3022e-04
# Epoch 28/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.8725e-04 - mse: 2.8725e-04 - val_loss: 3.5709e-05 - val_mse: 3.5709e-05
# Epoch 29/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.3054e-04 - mse: 2.3054e-04 - val_loss: 5.5505e-05 - val_mse: 5.5505e-05
# Epoch 30/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 2.3951e-04 - mse: 2.3951e-04 - val_loss: 1.2276e-04 - val_mse: 1.2276e-04
# Epoch 31/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.4393e-04 - mse: 2.4393e-04 - val_loss: 6.1760e-05 - val_mse: 6.1760e-05
# Epoch 32/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.6539e-04 - mse: 2.6539e-04 - val_loss: 1.5084e-04 - val_mse: 1.5084e-04
# Epoch 33/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 2.8513e-04 - mse: 2.8513e-04 - val_loss: 1.3260e-04 - val_mse: 1.3260e-04
# Epoch 34/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 3.3129e-04 - mse: 3.3129e-04 - val_loss: 5.5464e-05 - val_mse: 5.5464e-05
# Epoch 35/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 2.4765e-04 - mse: 2.4765e-04 - val_loss: 1.7326e-04 - val_mse: 1.7326e-04
# Epoch 36/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.0289e-04 - mse: 4.0289e-04 - val_loss: 1.0485e-04 - val_mse: 1.0485e-04
# Epoch 37/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 2.5887e-04 - mse: 2.5887e-04 - val_loss: 1.2081e-04 - val_mse: 1.2081e-04
# Epoch 38/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.9934e-04 - mse: 1.9934e-04 - val_loss: 1.7136e-04 - val_mse: 1.7136e-04
# Epoch 39/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 2.1394e-04 - mse: 2.1394e-04 - val_loss: 8.7472e-05 - val_mse: 8.7472e-05
# Epoch 40/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 2.2278e-04 - mse: 2.2278e-04 - val_loss: 6.8358e-05 - val_mse: 6.8358e-05
# Epoch 41/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.6065e-04 - mse: 2.6065e-04 - val_loss: 1.0540e-04 - val_mse: 1.0540e-04
# Epoch 42/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 1.8244e-04 - mse: 1.8244e-04 - val_loss: 5.7839e-05 - val_mse: 5.7839e-05
# Epoch 43/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.0776e-04 - mse: 2.0776e-04 - val_loss: 1.8373e-04 - val_mse: 1.8373e-04
# Epoch 44/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.9267e-04 - mse: 1.9267e-04 - val_loss: 2.4913e-04 - val_mse: 2.4913e-04
# Epoch 45/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.9436e-04 - mse: 2.9436e-04 - val_loss: 4.5395e-05 - val_mse: 4.5395e-05
# Epoch 46/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.9698e-04 - mse: 1.9698e-04 - val_loss: 8.3313e-05 - val_mse: 8.3313e-05
# Epoch 47/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 2.2372e-04 - mse: 2.2372e-04 - val_loss: 2.3303e-04 - val_mse: 2.3303e-04
# Epoch 48/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 3.5988e-04 - mse: 3.5988e-04 - val_loss: 2.5859e-05 - val_mse: 2.5859e-05
# Epoch 49/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 2.2058e-04 - mse: 2.2058e-04 - val_loss: 6.5083e-05 - val_mse: 6.5083e-05
# Epoch 50/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.9789e-04 - mse: 1.9789e-04 - val_loss: 6.9801e-05 - val_mse: 6.9801e-05

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print("x test shape:", xtest.shape)

# Directly predict (no reshape needed)
y_pred = best_model.predict(xtest)
y_pred = y_pred.flatten()

print("Prediction shape:", y_pred.shape)

mse = mean_squared_error(ytest, y_pred)
r2 = r2_score(ytest, y_pred)

# Change the print statement to reflect the correct metric
print(f" Mse : {mse:.6f}%")
print(f" r2 : {r2:.4f}")
# Out:
# x test shape: (974, 1, 4)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step
# Prediction shape: (974,)
#  Mse : 0.000070%
#  r2 : 0.9992

# %%
xtrain1,xtest1,ytrain1,ytest1 = train_test_split(X1,Y1,train_size=0.8,random_state=42)

# %%
xtrain1 = np.reshape(xtrain1, (xtrain1.shape[0],1, xtrain1.shape[1]))
xtest1 = xtest1.reshape((xtest1.shape[0], 1, xtest1.shape[1]))

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_lstm_model1(hp):

    model1 = Sequential()

    # Tune number of LSTM layers (1–3)
    for i in range(hp.Int("num_lstm_layers", 1, 3)):
        model1.add(
            LSTM(
                units=hp.Int(f"lstm_units_{i}", 32, 256, step=32),
                return_sequences=(i < hp.get("num_lstm_layers") - 1)
            )
        )
        model1.add(Dropout(
            hp.Float(f"dropout_{i}", 0.1, 0.5, step=0.1)
        ))

    # Dense layer tuning
    model1.add(Dense(
        units=hp.Int("dense_units", 16, 128, step=16),
        activation="relu"
    ))

    # Output layer
    model1.add(Dense(1))

    # Learning rate tuning
    lr = hp.Choice("learning_rate", [1e-2, 1e-3, 5e-4, 1e-4])

    model1.compile(
        optimizer=Adam(learning_rate=lr),
        loss="mean_squared_error",
        metrics=["mse"]
    )

    return model1

# %%
tuner1 = kt.BayesianOptimization(
    build_lstm_model1,
    objective="val_loss",
    max_trials=25,
    directory="lstm_bayesian_tuning",
    project_name="tcs_lstm1"
)

tuner1.search_space_summary()
# Out:
# Reloading Tuner from lstm_bayesian_tuning\tcs_lstm1\tuner0.json
# Search space summary
# Default search space size: 9
# num_lstm_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': 'linear'}
# lstm_units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_0 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# dense_units (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0005, 0.0001], 'ordered': True}
# lstm_units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_1 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# lstm_units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_2 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}

# %%
tuner1.search(
    xtrain1, ytrain1,
    epochs=15,
    validation_data=(xtest1, ytest1),
    verbose=1
)

# %%
best_hps1 = tuner1.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps1.values)
# Out:
# Best Hyperparameters: {'num_lstm_layers': 1, 'lstm_units_0': 128, 'dropout_0': 0.1, 'dense_units': 128, 'learning_rate': 0.0001, 'lstm_units_1': 160, 'dropout_1': 0.5, 'lstm_units_2': 32, 'dropout_2': 0.4}

# %%
best_model1 = tuner1.get_best_models(num_models=1)[0]
best_hps1 = tuner1.get_best_hyperparameters(num_trials=1)[0]

# If batch size was part of tuning:
if "batch_size" in best_hps1.values:
    batch_size1 = best_hps1.get("batch_size")
else:
    batch_size1 = 32   # fallback

history1 = best_model1.fit(
    xtrain1, ytrain1,
    validation_data=(xtest1, ytest1),
    epochs=50,
    batch_size=batch_size1,
    verbose=1
)
# Out:
# Epoch 1/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - loss: 2.8732e-04 - mse: 2.8732e-04 - val_loss: 1.7933e-05 - val_mse: 1.7933e-05
# Epoch 2/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6516e-04 - mse: 2.6516e-04 - val_loss: 2.2145e-05 - val_mse: 2.2145e-05
# Epoch 3/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2.4424e-04 - mse: 2.4424e-04 - val_loss: 2.6715e-05 - val_mse: 2.6715e-05
# Epoch 4/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2469e-04 - mse: 2.2469e-04 - val_loss: 1.6947e-05 - val_mse: 1.6947e-05
# Epoch 5/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.1681e-04 - mse: 2.1681e-04 - val_loss: 2.4735e-05 - val_mse: 2.4735e-05
# Epoch 6/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.2146e-04 - mse: 2.2146e-04 - val_loss: 1.9983e-05 - val_mse: 1.9983e-05
# Epoch 7/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0419e-04 - mse: 2.0419e-04 - val_loss: 1.5200e-05 - val_mse: 1.5200e-05
# Epoch 8/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9874e-04 - mse: 1.9874e-04 - val_loss: 2.7853e-05 - val_mse: 2.7853e-05
# Epoch 9/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.7799e-04 - mse: 1.7799e-04 - val_loss: 2.8071e-05 - val_mse: 2.8071e-05
# Epoch 10/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8486e-04 - mse: 1.8486e-04 - val_loss: 2.6445e-05 - val_mse: 2.6445e-05
# Epoch 11/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8568e-04 - mse: 1.8568e-04 - val_loss: 2.3748e-05 - val_mse: 2.3748e-05
# Epoch 12/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6877e-04 - mse: 1.6877e-04 - val_loss: 1.5367e-05 - val_mse: 1.5367e-05
# Epoch 13/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.7313e-04 - mse: 1.7313e-04 - val_loss: 3.0975e-05 - val_mse: 3.0975e-05
# Epoch 14/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.6719e-04 - mse: 1.6719e-04 - val_loss: 2.4678e-05 - val_mse: 2.4678e-05
# Epoch 15/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.6360e-04 - mse: 1.6360e-04 - val_loss: 2.5770e-05 - val_mse: 2.5770e-05
# Epoch 16/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5297e-04 - mse: 1.5297e-04 - val_loss: 3.0174e-05 - val_mse: 3.0174e-05
# Epoch 17/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.6395e-04 - mse: 1.6395e-04 - val_loss: 2.7654e-05 - val_mse: 2.7654e-05
# Epoch 18/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5471e-04 - mse: 1.5471e-04 - val_loss: 4.5035e-05 - val_mse: 4.5035e-05
# Epoch 19/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.6306e-04 - mse: 1.6306e-04 - val_loss: 2.0962e-05 - val_mse: 2.0962e-05
# Epoch 20/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4597e-04 - mse: 1.4597e-04 - val_loss: 1.7442e-05 - val_mse: 1.7442e-05
# Epoch 21/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4925e-04 - mse: 1.4925e-04 - val_loss: 2.6078e-05 - val_mse: 2.6078e-05
# Epoch 22/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5164e-04 - mse: 1.5164e-04 - val_loss: 1.9707e-05 - val_mse: 1.9707e-05
# Epoch 23/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3828e-04 - mse: 1.3828e-04 - val_loss: 7.1020e-05 - val_mse: 7.1020e-05
# Epoch 24/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4377e-04 - mse: 1.4377e-04 - val_loss: 2.4366e-05 - val_mse: 2.4366e-05
# Epoch 25/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.4291e-04 - mse: 1.4291e-04 - val_loss: 7.4221e-05 - val_mse: 7.4221e-05
# Epoch 26/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4452e-04 - mse: 1.4452e-04 - val_loss: 2.7256e-05 - val_mse: 2.7256e-05
# Epoch 27/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2768e-04 - mse: 1.2768e-04 - val_loss: 2.7396e-05 - val_mse: 2.7396e-05
# Epoch 28/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2316e-04 - mse: 1.2316e-04 - val_loss: 2.7982e-05 - val_mse: 2.7982e-05
# Epoch 29/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3360e-04 - mse: 1.3360e-04 - val_loss: 1.5593e-05 - val_mse: 1.5593e-05
# Epoch 30/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4199e-04 - mse: 1.4199e-04 - val_loss: 3.3862e-05 - val_mse: 3.3862e-05
# Epoch 31/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3586e-04 - mse: 1.3586e-04 - val_loss: 2.5515e-05 - val_mse: 2.5515e-05
# Epoch 32/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2734e-04 - mse: 1.2734e-04 - val_loss: 1.7624e-05 - val_mse: 1.7624e-05
# Epoch 33/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2386e-04 - mse: 1.2386e-04 - val_loss: 1.7896e-05 - val_mse: 1.7896e-05
# Epoch 34/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3124e-04 - mse: 1.3124e-04 - val_loss: 2.3896e-05 - val_mse: 2.3896e-05
# Epoch 35/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1585e-04 - mse: 1.1585e-04 - val_loss: 2.5752e-05 - val_mse: 2.5752e-05
# Epoch 36/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2418e-04 - mse: 1.2418e-04 - val_loss: 2.2831e-05 - val_mse: 2.2831e-05
# Epoch 37/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2375e-04 - mse: 1.2375e-04 - val_loss: 2.3549e-05 - val_mse: 2.3549e-05
# Epoch 38/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2628e-04 - mse: 1.2628e-04 - val_loss: 2.2536e-05 - val_mse: 2.2536e-05
# Epoch 39/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1784e-04 - mse: 1.1784e-04 - val_loss: 2.0861e-05 - val_mse: 2.0861e-05
# Epoch 40/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1106e-04 - mse: 1.1106e-04 - val_loss: 1.6820e-05 - val_mse: 1.6820e-05
# Epoch 41/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2311e-04 - mse: 1.2311e-04 - val_loss: 3.2558e-05 - val_mse: 3.2558e-05
# Epoch 42/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0892e-04 - mse: 1.0892e-04 - val_loss: 2.4687e-05 - val_mse: 2.4687e-05
# Epoch 43/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0653e-04 - mse: 1.0653e-04 - val_loss: 3.8418e-05 - val_mse: 3.8418e-05
# Epoch 44/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1173e-04 - mse: 1.1173e-04 - val_loss: 2.0132e-05 - val_mse: 2.0132e-05
# Epoch 45/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0602e-04 - mse: 1.0602e-04 - val_loss: 2.2459e-05 - val_mse: 2.2459e-05
# Epoch 46/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1245e-04 - mse: 1.1245e-04 - val_loss: 4.3666e-05 - val_mse: 4.3666e-05
# Epoch 47/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1462e-04 - mse: 1.1462e-04 - val_loss: 3.3708e-05 - val_mse: 3.3708e-05
# Epoch 48/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0494e-04 - mse: 1.0494e-04 - val_loss: 2.2751e-05 - val_mse: 2.2751e-05
# Epoch 49/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0366e-04 - mse: 1.0366e-04 - val_loss: 4.3131e-05 - val_mse: 4.3131e-05
# Epoch 50/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0466e-04 - mse: 1.0466e-04 - val_loss: 7.3663e-05 - val_mse: 7.3663e-05

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print("x test shape:", xtest1.shape)

# Directly predict (no reshape needed)
y_pred1 = best_model1.predict(xtest1)
y_pred1 = y_pred1.flatten()

print("Prediction shape:", y_pred1.shape)

mse1 = mean_squared_error(ytest1, y_pred1)
r2_1 = r2_score(ytest1, y_pred1)

# Change the print statement to reflect the correct metric
print(f" Mse : {mse1:.6f}%")
print(f" r2 : {r2_1:.4f}")
# Out:
# x test shape: (974, 1, 4)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction shape: (974,)
#  Mse : 0.000074%
#  r2 : 0.9991

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)

plt.title('Model Loss Curve', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(history1.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history1.history['val_loss'], label='Validation Loss', linewidth=2)

plt.title('Model Loss Curve', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(ytest,y_pred1,alpha=0.6,color="royalblue",edgecolor='k')

min_val=min(min(ytest),min(y_pred))
max_val = max(max(ytest),max(y_pred))

plt.plot([min_val,max_val],[min_val,max_val],color='red',linestyle='--',linewidth=2)
plt.title('Actual vs Predicted Values', fontsize=14)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(ytest1,y_pred1,alpha=0.6,color="royalblue",edgecolor='k')

min_val1=min(min(ytest1),min(y_pred1))
max_val1 = max(max(ytest1),max(y_pred1))

plt.plot([min_val1,max_val1],[min_val1,max_val1],color='red',linestyle='--',linewidth=2)
plt.title('Actual vs Predicted Values', fontsize=14)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [raw]
# use seperate scaler

# %%
y_pred_reshaped = y_pred.reshape(-1, 1)
y_pred_actual = scalery.inverse_transform(y_pred_reshaped)

# %%
y_pred_reshaped1 = y_pred1.reshape(-1, 1)
y_pred_actual1 = scalery1.inverse_transform(y_pred_reshaped1)

# %% [markdown]
# Hence,LSTM is the best one for the prediction

# %% [markdown]
# input values are "OPEN ","HIGH ","LOW ","PREV. CLOSE ","ltp ","52W H ","52W L ","VOLUME ","No of trades "

# %% [raw]
# op=float(input("Enter the open price:"))
# hi=float(input("Enter the High price in that time:"))
# lo=float(input("Enter the Low price in that time:"))
# pre=float(input("Enter the PREV.CLOSE:"))
# ltp=float(input("Enter the Real-time current price:"))
# fih=float(input("Enter the 52-week highest price:"))
# lih=float(input("Enter the 52-week lowest price:"))
# vol=int(input("Enter the volume:"))
# trad=int(input("Enter the Number of shares traded :"))

# %% [raw]
# def prediction(op,hi,lo,pre,ltp,fih,lih,vol,trad):
#     value =[[op,hi,lo,pre,ltp,fih,lih,vol,trad]]
#     value_1 = pd.DataFrame(value)
#     val = scalerx.fit_transform(value_1)
#     values = np.reshape(val, (val.shape[0], 1, val.shape[1]))
#     predict = model_lstm.predict(values)
#     return predict

# %% [raw]
# predict = prediction(op, hi, lo, pre, ltp, fih, lih, vol, trad)

# %% [raw]
# ypred = predict.reshape(-1, 1)
# y = scalery.inverse_transform(ypred)

# %% [raw]
# y

# %%
data = pd.read_csv(r"C:\Users\91984\Downloads\Quote-Equity-TCS-EQ-15-09-2025-to-15-10-2025.csv")

# %%
data
# Out:
#           Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0   15-Oct-2025      EQ  2,971.00  2,979.70  2,951.00     2,960.30  2,970.00
# 1   14-Oct-2025      EQ  3,021.00  3,027.20  2,955.50     3,007.20  2,960.00
# 2   13-Oct-2025      EQ  3,027.00  3,035.50  2,998.20     3,028.30  3,006.00
# 3   10-Oct-2025      EQ  3,050.00  3,070.00  3,006.90     3,061.70  3,028.00
# 4   09-Oct-2025      EQ  3,034.00  3,066.00  3,020.00     3,027.20  3,060.20
# 5   08-Oct-2025      EQ  2,975.00  3,043.00  2,968.00     2,973.70  3,031.50
# 6   07-Oct-2025      EQ  2,995.00  3,004.50  2,955.50     2,988.40  2,975.00
# 7   06-Oct-2025      EQ  2,902.00  2,993.60  2,895.60     2,901.90  2,988.00
# 8   03-Oct-2025      EQ  2,924.00  2,924.00  2,891.10     2,914.20  2,903.00
# 9   01-Oct-2025      EQ  2,891.00  2,924.80  2,866.60     2,888.40  2,915.10
# 10  30-Sep-2025      EQ  2,911.00  2,915.30  2,885.10     2,896.10  2,891.00
# 11  29-Sep-2025      EQ  2,916.00  2,929.30  2,894.00     2,899.10  2,904.30
# 12  26-Sep-2025      EQ  2,941.00  2,954.80  2,891.30     2,957.40  2,905.40
# 13  25-Sep-2025      EQ  3,022.00  3,029.60  2,951.00     3,035.40  2,958.00
# 14  24-Sep-2025      EQ  3,050.00  3,057.00  3,033.00     3,062.40  3,036.80
# 15  23-Sep-2025      EQ  3,070.00  3,080.70  3,052.00     3,073.80  3,065.00
# 16  22-Sep-2025      EQ  3,095.00  3,106.90  3,065.00     3,169.20  3,075.50
# 17  19-Sep-2025      EQ  3,170.00  3,180.50  3,144.00     3,176.70  3,171.00
# 18  18-Sep-2025      EQ  3,185.00  3,203.00  3,161.40     3,172.80  3,177.00
# 19  17-Sep-2025      EQ  3,152.00  3,182.40  3,142.40     3,145.70  3,175.00
# 20  16-Sep-2025      EQ  3,128.00  3,150.00  3,109.10     3,111.90  3,147.90
# 21  15-Sep-2025      EQ  3,134.00  3,134.00  3,096.00     3,133.40  3,112.50
#
#       close      vwap     52W H     52W L     VOLUME               VALUE   \
# 0   2,969.80  2,967.01  4,494.90  2,866.60  42,82,226  12,70,53,86,117.20
# 1   2,960.30  2,976.34  4,494.90  2,866.60  36,11,416  10,74,87,94,587.50
# 2   3,007.20  3,011.37  4,494.90  2,866.60  28,66,865   8,63,31,80,149.10
# 3   3,028.30  3,032.16  4,494.90  2,866.60  88,17,365  26,73,56,29,672.60
# 4   3,061.70  3,046.36  4,494.90  2,866.60  32,11,304   9,78,27,98,225.60
# 5   3,027.20  3,024.78  4,494.90  2,866.60  41,21,889  12,46,78,11,108.50
# 6   2,973.70  2,971.70  4,494.90  2,866.60  30,62,943   9,10,21,39,525.60
# 7   2,988.40  2,959.88  4,494.90  2,866.60  21,12,774   6,25,35,56,716.30
# 8   2,901.90  2,902.27  4,494.90  2,866.60  28,99,519   8,41,51,75,156.20
# 9   2,914.20  2,897.26  4,494.90  2,866.60  19,52,902   5,65,80,70,903.00
# 10  2,888.40  2,895.89  4,494.90  2,885.10  22,53,458   6,52,57,55,380.40
# 11  2,896.10  2,904.37  4,494.90  2,891.30  31,10,035   9,03,26,90,025.70
# 12  2,899.10  2,915.19  4,494.90  2,891.30  39,34,636  11,47,02,04,570.00
# 13  2,957.40  2,977.56  4,494.90  2,951.00  49,74,361  14,81,14,52,426.90
# 14  3,035.40  3,044.04  4,494.90  2,991.60  16,25,714   4,94,87,46,206.60
# 15  3,062.40  3,063.85  4,494.90  2,991.60  31,77,741   9,73,61,21,756.20
# 16  3,073.80  3,082.86  4,494.90  2,991.60  36,34,901  11,20,58,89,441.10
# 17  3,169.20  3,163.36  4,546.05  2,991.60  49,01,694  15,50,58,26,514.10
# 18  3,176.70  3,179.00  4,546.05  2,991.60  26,33,138   8,37,07,38,058.40
# 19  3,172.80  3,170.19  4,546.05  2,991.60  24,18,271   7,66,63,88,043.20
# 20  3,145.70  3,132.70  4,546.05  2,991.60  25,73,429   8,06,17,82,019.30
# 21  3,111.90  3,108.20  4,546.05  2,991.60  17,32,539   5,38,50,83,002.30
#
#    No of trades
# 0       1,46,773
# 1       1,83,673
# 2       1,69,572
# 3       2,44,153
# 4       1,33,703
# 5       1,54,336
# 6       1,41,987
# 7       1,00,920
# 8       1,56,466
# 9       1,24,217
# 10      2,01,510
# 11      1,79,197
# 12      3,90,339
# 13      4,18,858
# 14      1,01,133
# 15      1,41,198
# 16      3,21,272
# 17      1,09,280
# 18      1,47,801
# 19      1,00,973
# 20        96,675
# 21      1,45,801

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           22 non-null     object
#  1   series         22 non-null     object
#  2   OPEN           22 non-null     object
#  3   HIGH           22 non-null     object
#  4   LOW            22 non-null     object
#  5   PREV. CLOSE    22 non-null     object
#  6   ltp            22 non-null     object
#  7   close          22 non-null     object
#  8   vwap           22 non-null     object
#  9   52W H          22 non-null     object
#  10  52W L          22 non-null     object
#  11  VOLUME         22 non-null     object
#  12  VALUE          22 non-null     object
#  13  No of trades   22 non-null     object
# dtypes: object(14)
# memory usage: 2.5+ KB

# %%
numeric_columns = ["OPEN ","HIGH ","LOW ","PREV. CLOSE ","close ","ltp ","52W H ","52W L ","VOLUME ","No of trades "]

# %%
for i in numeric_columns:
    data[i]=data[i].str.replace(',','')
    data[i]=pd.to_numeric(data[i],errors='coerce')

# %%
data.drop(columns=['VALUE ','vwap ',"series ","PREV. CLOSE ","ltp ","52W H ","52W L ","No of trades "],inplace=True)

# %%
data['Date '] = pd.to_datetime(data['Date '])
data.set_index('Date ', inplace=True)

# %%
data
# Out:
#              OPEN    HIGH     LOW   close   VOLUME
# Date
# 2025-10-15  2971.0  2979.7  2951.0  2969.8  4282226
# 2025-10-14  3021.0  3027.2  2955.5  2960.3  3611416
# 2025-10-13  3027.0  3035.5  2998.2  3007.2  2866865
# 2025-10-10  3050.0  3070.0  3006.9  3028.3  8817365
# 2025-10-09  3034.0  3066.0  3020.0  3061.7  3211304
# 2025-10-08  2975.0  3043.0  2968.0  3027.2  4121889
# 2025-10-07  2995.0  3004.5  2955.5  2973.7  3062943
# 2025-10-06  2902.0  2993.6  2895.6  2988.4  2112774
# 2025-10-03  2924.0  2924.0  2891.1  2901.9  2899519
# 2025-10-01  2891.0  2924.8  2866.6  2914.2  1952902
# 2025-09-30  2911.0  2915.3  2885.1  2888.4  2253458
# 2025-09-29  2916.0  2929.3  2894.0  2896.1  3110035
# 2025-09-26  2941.0  2954.8  2891.3  2899.1  3934636
# 2025-09-25  3022.0  3029.6  2951.0  2957.4  4974361
# 2025-09-24  3050.0  3057.0  3033.0  3035.4  1625714
# 2025-09-23  3070.0  3080.7  3052.0  3062.4  3177741
# 2025-09-22  3095.0  3106.9  3065.0  3073.8  3634901
# 2025-09-19  3170.0  3180.5  3144.0  3169.2  4901694
# 2025-09-18  3185.0  3203.0  3161.4  3176.7  2633138
# 2025-09-17  3152.0  3182.4  3142.4  3172.8  2418271
# 2025-09-16  3128.0  3150.0  3109.1  3145.7  2573429
# 2025-09-15  3134.0  3134.0  3096.0  3111.9  1732539

# %% [raw]
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume'
#  ["OPEN ","HIGH ","LOW ","PREV. CLOSE ","ltp ","52W H ","52W L ","VOLUME ","No of trades "]

# %%
data = data.rename(columns={"Date ":"Date","OPEN ":"Open","HIGH ":'High',"LOW ":'Low','close ':"Close","VOLUME ":'Volume'})

# %%
data["Close"]
# Out:
# Date
# 2025-10-15    2969.8
# 2025-10-14    2960.3
# 2025-10-13    3007.2
# 2025-10-10    3028.3
# 2025-10-09    3061.7
# 2025-10-08    3027.2
# 2025-10-07    2973.7
# 2025-10-06    2988.4
# 2025-10-03    2901.9
# 2025-10-01    2914.2
# 2025-09-30    2888.4
# 2025-09-29    2896.1
# 2025-09-26    2899.1
# 2025-09-25    2957.4
# 2025-09-24    3035.4
# 2025-09-23    3062.4
# 2025-09-22    3073.8
# 2025-09-19    3169.2
# 2025-09-18    3176.7
# 2025-09-17    3172.8
# 2025-09-16    3145.7
# 2025-09-15    3111.9
# Name: Close, dtype: float64

# %%
X1=data.drop(columns ="Close")
value = scalerx.transform(X1)
value = np.reshape(value, (value.shape[0], 1, value.shape[1]))
predict = best_model.predict(value)
predict = np.array(predict).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step

# %%
value1 = scalerx1.transform(X1)
value1 = np.reshape(value1, (value1.shape[0], 1, value1.shape[1]))
predict1 = best_model1.predict(value1)
predict1 = np.array(predict1).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step

# %%
y1 = predict.reshape(-1, 1)
y1 = scalery.inverse_transform(y1)

# %%
y2 = predict1.reshape(-1, 1)
y2 = scalery1.inverse_transform(y2)

# %%
y2
# Out:
# array([[2930.6753],
#        [2965.2053],
#        [2978.7957],
#        [3006.228 ],
#        [2998.8948],
#        [2959.4988],
#        [2946.8992],
#        [2893.963 ],
#        [2877.9702],
#        [2858.0073],
#        [2866.805 ],
#        [2878.7546],
#        [2895.2908],
#        [2967.213 ],
#        [3000.2122],
#        [3024.1316],
#        [3046.6375],
#        [3123.2883],
#        [3131.9946],
#        [3108.063 ],
#        [3080.4607],
#        [3071.5164]], dtype=float32)

# %%
y2
# Out:
# array([[2930.6753],
#        [2965.2053],
#        [2978.7957],
#        [3006.228 ],
#        [2998.8948],
#        [2959.4988],
#        [2946.8992],
#        [2893.963 ],
#        [2877.9702],
#        [2858.0073],
#        [2866.805 ],
#        [2878.7546],
#        [2895.2908],
#        [2967.213 ],
#        [3000.2122],
#        [3024.1316],
#        [3046.6375],
#        [3123.2883],
#        [3131.9946],
#        [3108.063 ],
#        [3080.4607],
#        [3071.5164]], dtype=float32)

# %%
data
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2025-10-15  2971.0  2979.7  2951.0  2969.8  4282226
# 2025-10-14  3021.0  3027.2  2955.5  2960.3  3611416
# 2025-10-13  3027.0  3035.5  2998.2  3007.2  2866865
# 2025-10-10  3050.0  3070.0  3006.9  3028.3  8817365
# 2025-10-09  3034.0  3066.0  3020.0  3061.7  3211304
# 2025-10-08  2975.0  3043.0  2968.0  3027.2  4121889
# 2025-10-07  2995.0  3004.5  2955.5  2973.7  3062943
# 2025-10-06  2902.0  2993.6  2895.6  2988.4  2112774
# 2025-10-03  2924.0  2924.0  2891.1  2901.9  2899519
# 2025-10-01  2891.0  2924.8  2866.6  2914.2  1952902
# 2025-09-30  2911.0  2915.3  2885.1  2888.4  2253458
# 2025-09-29  2916.0  2929.3  2894.0  2896.1  3110035
# 2025-09-26  2941.0  2954.8  2891.3  2899.1  3934636
# 2025-09-25  3022.0  3029.6  2951.0  2957.4  4974361
# 2025-09-24  3050.0  3057.0  3033.0  3035.4  1625714
# 2025-09-23  3070.0  3080.7  3052.0  3062.4  3177741
# 2025-09-22  3095.0  3106.9  3065.0  3073.8  3634901
# 2025-09-19  3170.0  3180.5  3144.0  3169.2  4901694
# 2025-09-18  3185.0  3203.0  3161.4  3176.7  2633138
# 2025-09-17  3152.0  3182.4  3142.4  3172.8  2418271
# 2025-09-16  3128.0  3150.0  3109.1  3145.7  2573429
# 2025-09-15  3134.0  3134.0  3096.0  3111.9  1732539

# %%
y=data["Close"].values.reshape(-1, 1)

# %%
y
# Out:
# array([[2969.8],
#        [2960.3],
#        [3007.2],
#        [3028.3],
#        [3061.7],
#        [3027.2],
#        [2973.7],
#        [2988.4],
#        [2901.9],
#        [2914.2],
#        [2888.4],
#        [2896.1],
#        [2899.1],
#        [2957.4],
#        [3035.4],
#        [3062.4],
#        [3073.8],
#        [3169.2],
#        [3176.7],
#        [3172.8],
#        [3145.7],
#        [3111.9]])

# %%
mse = mean_squared_error(y1, y)
r2 = r2_score(y1, y)

print(f" Mse : {mse:.6f}%")
print(f" r2 : {r2:.4f}")
# Out:
#  Mse : 1915.877799%
#  r2 : 0.7222

# %%
mse = mean_squared_error(y2, y)
r2 = r2_score(y2, y)

print(f" Mse : {mse:.6f}%")
print(f" r2 : {r2:.4f}")
# Out:
#  Mse : 1965.747625%
#  r2 : 0.7183

# %%
plt.figure(figsize=(10,4))
plt.plot(y,label="acutual value",linewidth=2)
plt.plot(y1,label="predicted value",linewidth=2)
plt.title("Actualvs prediction value of one month(10 year data)",fontsize=22)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(y,label="acutual value",linewidth=2)
plt.plot(y2,label="predicted value",linewidth=2)
plt.title("Actualvs prediction value of one month(all year data)",fontsize=22)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
