# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\91984\Downloads\TCS_historical_data_Daily_5_Years.csv")

# %%
df
# Out:
#             Date    Open     High      Low    Close   Volume Exchange
# 0     2025-10-03  2924.0  2924.00  2891.10  2903.00  2799767      NSE
# 1     2025-10-01  2891.0  2924.80  2866.60  2916.80  1941068      NSE
# 2     2025-09-30  2911.0  2915.30  2885.10  2894.90  2228350      NSE
# 3     2025-09-29  2916.0  2929.30  2894.00  2904.30  3084635      NSE
# 4     2025-09-26  2941.0  2954.80  2891.30  2905.40  3876112      NSE
# ...          ...     ...      ...      ...      ...      ...      ...
# 1227  2020-10-23  2687.8  2702.00  2670.10  2686.80  3499372      NSE
# 1228  2020-10-22  2661.0  2686.65  2638.10  2671.15  5262311      NSE
# 1229  2020-10-21  2739.0  2749.00  2663.05  2675.40  4570175      NSE
# 1230  2020-10-20  2725.0  2759.90  2717.95  2739.00  3406298      NSE
# 1231  2020-10-19  2774.0  2774.00  2706.60  2711.55  3331194      NSE
#
# [1232 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1232 non-null   object
#  1   Open      1232 non-null   float64
#  2   High      1232 non-null   float64
#  3   Low       1232 non-null   float64
#  4   Close     1232 non-null   float64
#  5   Volume    1232 non-null   int64
#  6   Exchange  1232 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 67.5+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Exchange'], dtype='object')

# %%
df.drop(columns=['Exchange'],inplace=True)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1232.000000  1232.000000  1232.000000  1232.000000  1.232000e+03
# mean   3512.356006  3543.268709  3480.006818  3510.871510  2.429368e+06
# std     407.145359   412.034451   403.722241   407.448146  1.293514e+06
# min    2604.000000  2655.000000  2600.050000  2604.600000  6.505700e+04
# 25%    3218.125000  3243.700000  3192.000000  3215.325000  1.622162e+06
# 50%    3435.000000  3464.850000  3410.950000  3440.875000  2.084541e+06
# 75%    3810.000000  3840.312500  3772.250000  3810.950000  2.898771e+06
# max    4576.000000  4592.250000  4512.000000  4553.750000  1.350916e+07

# %%
df=df.copy(deep=True)
col=['Open', 'High', 'Low', 'Close', 'Volume']

# %%
df['Date'] = pd.to_datetime(df['Date'])
#df.set_index('Date', inplace=True)

# %%
for i in col:
    q25,q75=np.percentile(df[i],25),np.percentile(df[i],75)
    IQR = q75 - q25
    Threshold=IQR*1.5
    lower,upper=q25-Threshold,q75+Threshold
    outliers=[j for j in df[i] if j < lower or j > upper]
    for k in outliers:
        data_1=df.drop(df.index[df[i]==k],axis=0)

# %%
df=data_1
dt=df.copy()

# %%
df
# Out:
#            Date     Open     High      Low    Close   Volume
# 0    2025-10-03  2924.00  2924.00  2891.10  2903.00  2799767
# 1    2025-10-01  2891.00  2924.80  2866.60  2916.80  1941068
# 2    2025-09-30  2911.00  2915.30  2885.10  2894.90  2228350
# 3    2025-09-29  2916.00  2929.30  2894.00  2904.30  3084635
# 4    2025-09-26  2941.00  2954.80  2891.30  2905.40  3876112
# ...         ...      ...      ...      ...      ...      ...
# 1226 2020-10-26  2689.95  2709.95  2670.50  2688.20  2672766
# 1227 2020-10-23  2687.80  2702.00  2670.10  2686.80  3499372
# 1229 2020-10-21  2739.00  2749.00  2663.05  2675.40  4570175
# 1230 2020-10-20  2725.00  2759.90  2717.95  2739.00  3406298
# 1231 2020-10-19  2774.00  2774.00  2706.60  2711.55  3331194
#
# [1231 rows x 6 columns]

# %%
fig = go.Figure([go.Ohlc(x=dt.Date,
                         open=dt.Open,
                         high=dt.High,
                         low=dt.Low,
                         close=dt.Close)])

fig.update_layout(
    xaxis_rangeslider_visible=False,
    width=1200,      # change width
    height=700      # change height
)

fig.show()

# %%
fig = go.Figure(go.Bar(x=dt.Date, y=dt.Volume, name='Volume', marker_color='red'))
fig.update_layout(
    width=1000,      # change width
    height=500      # change height
)
fig.show()

# %%
df
# Out:
#            Date     Open     High      Low    Close   Volume
# 0    2025-10-03  2924.00  2924.00  2891.10  2903.00  2799767
# 1    2025-10-01  2891.00  2924.80  2866.60  2916.80  1941068
# 2    2025-09-30  2911.00  2915.30  2885.10  2894.90  2228350
# 3    2025-09-29  2916.00  2929.30  2894.00  2904.30  3084635
# 4    2025-09-26  2941.00  2954.80  2891.30  2905.40  3876112
# ...         ...      ...      ...      ...      ...      ...
# 1226 2020-10-26  2689.95  2709.95  2670.50  2688.20  2672766
# 1227 2020-10-23  2687.80  2702.00  2670.10  2686.80  3499372
# 1229 2020-10-21  2739.00  2749.00  2663.05  2675.40  4570175
# 1230 2020-10-20  2725.00  2759.90  2717.95  2739.00  3406298
# 1231 2020-10-19  2774.00  2774.00  2706.60  2711.55  3331194
#
# [1231 rows x 6 columns]

# %%
dt['EMA_9'] = dt['Close'].ewm(5).mean().shift()
dt['SMA_50'] = dt['Close'].rolling(50).mean().shift()
dt['SMA_100'] = dt['Close'].rolling(100).mean().shift()
dt['SMA_200'] = dt['Close'].rolling(200).mean().shift()

fig = go.Figure()
fig.add_trace(go.Scatter(x=dt.Date, y=dt.EMA_9, name='EMA 9'))
fig.add_trace(go.Scatter(x=dt.Date, y=dt.SMA_50, name='SMA 50'))
fig.add_trace(go.Scatter(x=dt.Date, y=dt.SMA_100, name='SMA 100'))
fig.add_trace(go.Scatter(x=dt.Date, y=dt.SMA_200, name='SMA 200'))
fig.add_trace(go.Scatter(x=dt.Date, y=dt.Close, name='Close', line_color='dimgray', opacity=0.3))
fig.update_layout(
    width=1100,      # change width
    height=700      # change height
)
fig.show()

# %%
df
# Out:
#            Date     Open     High      Low    Close   Volume
# 0    2025-10-03  2924.00  2924.00  2891.10  2903.00  2799767
# 1    2025-10-01  2891.00  2924.80  2866.60  2916.80  1941068
# 2    2025-09-30  2911.00  2915.30  2885.10  2894.90  2228350
# 3    2025-09-29  2916.00  2929.30  2894.00  2904.30  3084635
# 4    2025-09-26  2941.00  2954.80  2891.30  2905.40  3876112
# ...         ...      ...      ...      ...      ...      ...
# 1226 2020-10-26  2689.95  2709.95  2670.50  2688.20  2672766
# 1227 2020-10-23  2687.80  2702.00  2670.10  2686.80  3499372
# 1229 2020-10-21  2739.00  2749.00  2663.05  2675.40  4570175
# 1230 2020-10-20  2725.00  2759.90  2717.95  2739.00  3406298
# 1231 2020-10-19  2774.00  2774.00  2706.60  2711.55  3331194
#
# [1231 rows x 6 columns]

# %%
def RSI(dt, n=14):
    close = dt['Close']
    delta = close.diff()
    delta = delta[1:]
    pricesUp = delta.copy()
    pricesDown = delta.copy()
    pricesUp[pricesUp < 0] = 0
    pricesDown[pricesDown > 0] = 0
    rollUp = pricesUp.rolling(n).mean()
    rollDown = pricesDown.abs().rolling(n).mean()
    rs = rollUp / rollDown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

num_days = 365
dt['RSI'] = RSI(dt).fillna(0)

fig = go.Figure(
    go.Scatter(
        x=dt.Date.tail(num_days),
        y=dt.RSI.tail(num_days)
    )
)

fig.update_layout(
    width=1100,   # change width
    height=600,  # change height
    title="RSI Chart"
)

fig.show()

# %%
def stochastic(dt, k, d):
    dt = dt.copy()
    low_min  = dt['Low'].rolling(window=k).min()
    high_max = dt['High'].rolling( window=k).max()
    dt['stoch_k'] = 100 * (dt['Close'] - low_min)/(high_max - low_min)
    dt['stoch_d'] = dt['stoch_k'].rolling(window=d).mean()
    return dt

stochs = stochastic(dt, k=14, d=3)

fig = go.Figure()
fig.add_trace(go.Scatter(x=dt.Date.tail(365), y=stochs.stoch_k.tail(365), name='K stochastic'))
fig.add_trace(go.Scatter(x=dt.Date.tail(365), y=stochs.stoch_d.tail(365), name='D stochastic'))
fig.update_layout(
    width=1100,   # change width
    height=600,  # change height
    title="Stochastic"
)
fig.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
from sklearn.preprocessing import MinMaxScaler
features = ['Open', 'High', 'Low', 'Volume']
scalerx = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X=scalerx.fit_transform(df[features])

# %%
Y=scalery.fit_transform(df[["Close"]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,train_size=0.8,random_state=42)

# %%
df.shape
# Out:
# (1231, 6)

# %%
xtrain.shape
# Out:
# (984, 4)

# %%
xtrain = xtrain.reshape((xtrain.shape[0], 1, xtrain.shape[1]))
xtest = xtest.reshape((xtest.shape[0], 1, xtest.shape[1]))

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_lstm_model(hp):

    model = Sequential()

    # Tune number of LSTM layers (1–3)
    for i in range(hp.Int("num_lstm_layers", 1, 3)):
        model.add(
            LSTM(
                units=hp.Int(f"lstm_units_{i}", 32, 256, step=32),
                return_sequences=(i < hp.get("num_lstm_layers") - 1)
            )
        )
        model.add(Dropout(
            hp.Float(f"dropout_{i}", 0.1, 0.5, step=0.1)
        ))

    # Dense layer tuning
    model.add(Dense(
        units=hp.Int("dense_units", 16, 128, step=16),
        activation="relu"
    ))

    # Output layer
    model.add(Dense(1))

    # Learning rate tuning
    lr = hp.Choice("learning_rate", [1e-2, 1e-3, 5e-4, 1e-4])

    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss="mean_squared_error",
        metrics=["mse"]
    )

    return model

# %%
tuner = kt.BayesianOptimization(
    build_lstm_model,
    objective="val_loss",
    max_trials=25,
    directory="lstm_bayesian_tuning",
    project_name="tcs_lstm"
)

tuner.search_space_summary()
# Out:
# Reloading Tuner from lstm_bayesian_tuning\tcs_lstm\tuner0.json
# Search space summary
# Default search space size: 9
# num_lstm_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': 'linear'}
# lstm_units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_0 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# dense_units (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0005, 0.0001], 'ordered': True}
# lstm_units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_1 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# lstm_units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_2 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}

# %%
tuner.search(
    xtrain, ytrain,
    epochs=15,
    validation_data=(xtest, ytest),
    verbose=1
)

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps.values)
# Out:
# Best Hyperparameters: {'num_lstm_layers': 2, 'lstm_units_0': 96, 'dropout_0': 0.30000000000000004, 'dense_units': 32, 'learning_rate': 0.01, 'lstm_units_1': 128, 'dropout_1': 0.1, 'lstm_units_2': 64, 'dropout_2': 0.4}

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# If batch size was part of tuning:
if "batch_size" in best_hps.values:
    batch_size = best_hps.get("batch_size")
else:
    batch_size = 32   # fallback

history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs=50,
    batch_size=batch_size,
    verbose=1
)
# Out:
# WARNING:tensorflow:From C:\Users\91984\Desktop\project\my_venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 3.9841e-04 - val_mse: 3.9841e-04
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4790e-04 - mse: 9.4790e-04 - val_loss: 7.0837e-04 - val_mse: 7.0837e-04
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3599e-04 - mse: 7.3599e-04 - val_loss: 3.1337e-04 - val_mse: 3.1337e-04
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9220e-04 - mse: 5.9220e-04 - val_loss: 3.6223e-04 - val_mse: 3.6223e-04
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4500e-04 - mse: 8.4500e-04 - val_loss: 3.0935e-04 - val_mse: 3.0935e-04
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4266e-04 - mse: 6.4266e-04 - val_loss: 2.0466e-04 - val_mse: 2.0466e-04
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7449e-04 - mse: 5.7449e-04 - val_loss: 2.2341e-04 - val_mse: 2.2341e-04
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8122e-04 - mse: 5.8122e-04 - val_loss: 1.9457e-04 - val_mse: 1.9457e-04
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6442e-04 - mse: 6.6442e-04 - val_loss: 2.5144e-04 - val_mse: 2.5144e-04
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9565e-04 - mse: 6.9565e-04 - val_loss: 5.7011e-04 - val_mse: 5.7011e-04
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3045e-04 - mse: 6.3045e-04 - val_loss: 2.9778e-04 - val_mse: 2.9778e-04
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 3.0397e-04 - val_mse: 3.0397e-04
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5000e-04 - mse: 6.5000e-04 - val_loss: 3.4249e-04 - val_mse: 3.4249e-04
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7346e-04 - mse: 7.7346e-04 - val_loss: 3.4974e-04 - val_mse: 3.4974e-04
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2832e-04 - mse: 6.2832e-04 - val_loss: 4.8319e-04 - val_mse: 4.8319e-04
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6768e-04 - mse: 7.6768e-04 - val_loss: 4.7904e-04 - val_mse: 4.7904e-04
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2845e-04 - mse: 8.2845e-04 - val_loss: 3.8607e-04 - val_mse: 3.8607e-04
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6514e-04 - mse: 6.6514e-04 - val_loss: 2.6903e-04 - val_mse: 2.6903e-04
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3785e-04 - mse: 6.3785e-04 - val_loss: 4.7061e-04 - val_mse: 4.7061e-04
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7723e-04 - mse: 5.7723e-04 - val_loss: 1.7660e-04 - val_mse: 1.7660e-04
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4231e-04 - mse: 6.4231e-04 - val_loss: 5.8949e-04 - val_mse: 5.8949e-04
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6438e-04 - mse: 5.6438e-04 - val_loss: 4.7005e-04 - val_mse: 4.7005e-04
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5608e-04 - mse: 8.5608e-04 - val_loss: 5.4691e-04 - val_mse: 5.4691e-04
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9733e-04 - mse: 7.9733e-04 - val_loss: 1.6505e-04 - val_mse: 1.6505e-04
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2795e-04 - mse: 5.2795e-04 - val_loss: 5.0379e-04 - val_mse: 5.0379e-04
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0572e-04 - mse: 5.0572e-04 - val_loss: 1.6900e-04 - val_mse: 1.6900e-04
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6473e-04 - mse: 5.6473e-04 - val_loss: 1.4611e-04 - val_mse: 1.4611e-04
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4036e-04 - mse: 5.4036e-04 - val_loss: 3.1530e-04 - val_mse: 3.1530e-04
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1987e-04 - mse: 6.1987e-04 - val_loss: 3.0706e-04 - val_mse: 3.0706e-04
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3834e-04 - mse: 6.3834e-04 - val_loss: 6.0490e-04 - val_mse: 6.0490e-04
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5672e-04 - mse: 7.5672e-04 - val_loss: 4.5326e-04 - val_mse: 4.5326e-04
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5665e-04 - mse: 5.5665e-04 - val_loss: 3.1763e-04 - val_mse: 3.1763e-04
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1241e-04 - mse: 8.1241e-04 - val_loss: 1.7345e-04 - val_mse: 1.7345e-04
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7320e-04 - mse: 6.7320e-04 - val_loss: 1.6584e-04 - val_mse: 1.6584e-04
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3846e-04 - mse: 5.3846e-04 - val_loss: 2.8406e-04 - val_mse: 2.8406e-04
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4516e-04 - mse: 6.4516e-04 - val_loss: 1.7809e-04 - val_mse: 1.7809e-04
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9099e-04 - mse: 6.9099e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2381e-04 - mse: 6.2381e-04 - val_loss: 3.6837e-04 - val_mse: 3.6837e-04
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2909e-04 - mse: 6.2909e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 3.2959e-04 - val_mse: 3.2959e-04
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6464e-04 - mse: 7.6464e-04 - val_loss: 2.9903e-04 - val_mse: 2.9903e-04
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8953e-04 - mse: 4.8953e-04 - val_loss: 2.0727e-04 - val_mse: 2.0727e-04
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6668e-04 - mse: 6.6668e-04 - val_loss: 2.2938e-04 - val_mse: 2.2938e-04
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3781e-04 - mse: 5.3781e-04 - val_loss: 2.3519e-04 - val_mse: 2.3519e-04
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4350e-04 - mse: 7.4350e-04 - val_loss: 2.3965e-04 - val_mse: 2.3965e-04
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3576e-04 - mse: 4.3576e-04 - val_loss: 3.1804e-04 - val_mse: 3.1804e-04
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4151e-04 - mse: 5.4151e-04 - val_loss: 3.7366e-04 - val_mse: 3.7366e-04
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6368e-04 - mse: 5.6368e-04 - val_loss: 3.7681e-04 - val_mse: 3.7681e-04
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2117e-04 - mse: 5.2117e-04 - val_loss: 2.7388e-04 - val_mse: 2.7388e-04
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2813e-04 - mse: 6.2813e-04 - val_loss: 2.7828e-04 - val_mse: 2.7828e-04

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print("x test shape:", xtest.shape)

# Directly predict (no reshape needed)
y_pred = best_model.predict(xtest)
y_pred = y_pred.flatten()

r2 = r2_score(ytest, y_pred1)

# Change the print statement to reflect the correct metric
print(f" Mse : {mse:.6f}%")
print(f" r2 : {r2:.4f}")
# Out:
# x test shape: (247, 1, 4)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#  Mse : 408.587020%
#  r2 : 0.9939

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)

plt.title('Model Loss Curve', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fix shape issues
ytest = np.array(ytest).flatten()
y_pred1 = np.array(y_pred1).flatten()

plt.figure(figsize=(10,8))
plt.scatter(ytest, y_pred1, alpha=0.6, color="royalblue", edgecolor='k')

min_val = min(min(ytest), min(y_pred1))
max_val = max(max(ytest), max(y_pred1))

# Perfect prediction line
plt.plot([min_val, max_val],
         [min_val, max_val],
         color='red',
         linestyle='--',
         linewidth=2,
         label='Perfect Prediction Line')

plt.title('Actual vs Predicted Values', fontsize=14)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [raw]
# use seperate scaler

# %%
y_pred_reshaped = y_pred1.reshape(-1, 1)
y_pred_actual = scalery.inverse_transform(y_pred_reshaped)

# %% [markdown]
# Hence,LSTM is the best one for the prediction

# %% [markdown]
# input values are "OPEN ","HIGH ","LOW ","PREV. CLOSE ","ltp ","52W H ","52W L ","VOLUME ","No of trades "

# %% [raw]
# op=float(input("Enter the open price:"))
# hi=float(input("Enter the High price in that time:"))
# lo=float(input("Enter the Low price in that time:"))
# pre=float(input("Enter the PREV.CLOSE:"))
# ltp=float(input("Enter the Real-time current price:"))
# fih=float(input("Enter the 52-week highest price:"))
# lih=float(input("Enter the 52-week lowest price:"))
# vol=int(input("Enter the volume:"))
# trad=int(input("Enter the Number of shares traded :"))

# %% [raw]
# def prediction(op,hi,lo,pre,ltp,fih,lih,vol,trad):
#     value =[[op,hi,lo,pre,ltp,fih,lih,vol,trad]]
#     value_1 = pd.DataFrame(value)
#     val = scalerx.fit_transform(value_1)
#     values = np.reshape(val, (val.shape[0], 1, val.shape[1]))
#     predict = model_lstm.predict(values)
#     return predict

# %% [raw]
# predict = prediction(op, hi, lo, pre, ltp, fih, lih, vol, trad)

# %% [raw]
# ypred = predict.reshape(-1, 1)
# y = scalery.inverse_transform(ypred)

# %% [raw]
# y

# %%
data = pd.read_csv(r"C:\Users\91984\Downloads\Quote-Equity-TCS-EQ-15-09-2025-to-15-10-2025.csv")

# %%
data
# Out:
#           Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0   15-Oct-2025      EQ  2,971.00  2,979.70  2,951.00     2,960.30  2,970.00
# 1   14-Oct-2025      EQ  3,021.00  3,027.20  2,955.50     3,007.20  2,960.00
# 2   13-Oct-2025      EQ  3,027.00  3,035.50  2,998.20     3,028.30  3,006.00
# 3   10-Oct-2025      EQ  3,050.00  3,070.00  3,006.90     3,061.70  3,028.00
# 4   09-Oct-2025      EQ  3,034.00  3,066.00  3,020.00     3,027.20  3,060.20
# 5   08-Oct-2025      EQ  2,975.00  3,043.00  2,968.00     2,973.70  3,031.50
# 6   07-Oct-2025      EQ  2,995.00  3,004.50  2,955.50     2,988.40  2,975.00
# 7   06-Oct-2025      EQ  2,902.00  2,993.60  2,895.60     2,901.90  2,988.00
# 8   03-Oct-2025      EQ  2,924.00  2,924.00  2,891.10     2,914.20  2,903.00
# 9   01-Oct-2025      EQ  2,891.00  2,924.80  2,866.60     2,888.40  2,915.10
# 10  30-Sep-2025      EQ  2,911.00  2,915.30  2,885.10     2,896.10  2,891.00
# 11  29-Sep-2025      EQ  2,916.00  2,929.30  2,894.00     2,899.10  2,904.30
# 12  26-Sep-2025      EQ  2,941.00  2,954.80  2,891.30     2,957.40  2,905.40
# 13  25-Sep-2025      EQ  3,022.00  3,029.60  2,951.00     3,035.40  2,958.00
# 14  24-Sep-2025      EQ  3,050.00  3,057.00  3,033.00     3,062.40  3,036.80
# 15  23-Sep-2025      EQ  3,070.00  3,080.70  3,052.00     3,073.80  3,065.00
# 16  22-Sep-2025      EQ  3,095.00  3,106.90  3,065.00     3,169.20  3,075.50
# 17  19-Sep-2025      EQ  3,170.00  3,180.50  3,144.00     3,176.70  3,171.00
# 18  18-Sep-2025      EQ  3,185.00  3,203.00  3,161.40     3,172.80  3,177.00
# 19  17-Sep-2025      EQ  3,152.00  3,182.40  3,142.40     3,145.70  3,175.00
# 20  16-Sep-2025      EQ  3,128.00  3,150.00  3,109.10     3,111.90  3,147.90
# 21  15-Sep-2025      EQ  3,134.00  3,134.00  3,096.00     3,133.40  3,112.50
#
#       close      vwap     52W H     52W L     VOLUME               VALUE   \
# 0   2,969.80  2,967.01  4,494.90  2,866.60  42,82,226  12,70,53,86,117.20
# 1   2,960.30  2,976.34  4,494.90  2,866.60  36,11,416  10,74,87,94,587.50
# 2   3,007.20  3,011.37  4,494.90  2,866.60  28,66,865   8,63,31,80,149.10
# 3   3,028.30  3,032.16  4,494.90  2,866.60  88,17,365  26,73,56,29,672.60
# 4   3,061.70  3,046.36  4,494.90  2,866.60  32,11,304   9,78,27,98,225.60
# 5   3,027.20  3,024.78  4,494.90  2,866.60  41,21,889  12,46,78,11,108.50
# 6   2,973.70  2,971.70  4,494.90  2,866.60  30,62,943   9,10,21,39,525.60
# 7   2,988.40  2,959.88  4,494.90  2,866.60  21,12,774   6,25,35,56,716.30
# 8   2,901.90  2,902.27  4,494.90  2,866.60  28,99,519   8,41,51,75,156.20
# 9   2,914.20  2,897.26  4,494.90  2,866.60  19,52,902   5,65,80,70,903.00
# 10  2,888.40  2,895.89  4,494.90  2,885.10  22,53,458   6,52,57,55,380.40
# 11  2,896.10  2,904.37  4,494.90  2,891.30  31,10,035   9,03,26,90,025.70
# 12  2,899.10  2,915.19  4,494.90  2,891.30  39,34,636  11,47,02,04,570.00
# 13  2,957.40  2,977.56  4,494.90  2,951.00  49,74,361  14,81,14,52,426.90
# 14  3,035.40  3,044.04  4,494.90  2,991.60  16,25,714   4,94,87,46,206.60
# 15  3,062.40  3,063.85  4,494.90  2,991.60  31,77,741   9,73,61,21,756.20
# 16  3,073.80  3,082.86  4,494.90  2,991.60  36,34,901  11,20,58,89,441.10
# 17  3,169.20  3,163.36  4,546.05  2,991.60  49,01,694  15,50,58,26,514.10
# 18  3,176.70  3,179.00  4,546.05  2,991.60  26,33,138   8,37,07,38,058.40
# 19  3,172.80  3,170.19  4,546.05  2,991.60  24,18,271   7,66,63,88,043.20
# 20  3,145.70  3,132.70  4,546.05  2,991.60  25,73,429   8,06,17,82,019.30
# 21  3,111.90  3,108.20  4,546.05  2,991.60  17,32,539   5,38,50,83,002.30
#
#    No of trades
# 0       1,46,773
# 1       1,83,673
# 2       1,69,572
# 3       2,44,153
# 4       1,33,703
# 5       1,54,336
# 6       1,41,987
# 7       1,00,920
# 8       1,56,466
# 9       1,24,217
# 10      2,01,510
# 11      1,79,197
# 12      3,90,339
# 13      4,18,858
# 14      1,01,133
# 15      1,41,198
# 16      3,21,272
# 17      1,09,280
# 18      1,47,801
# 19      1,00,973
# 20        96,675
# 21      1,45,801

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           22 non-null     object
#  1   series         22 non-null     object
#  2   OPEN           22 non-null     object
#  3   HIGH           22 non-null     object
#  4   LOW            22 non-null     object
#  5   PREV. CLOSE    22 non-null     object
#  6   ltp            22 non-null     object
#  7   close          22 non-null     object
#  8   vwap           22 non-null     object
#  9   52W H          22 non-null     object
#  10  52W L          22 non-null     object
#  11  VOLUME         22 non-null     object
#  12  VALUE          22 non-null     object
#  13  No of trades   22 non-null     object
# dtypes: object(14)
# memory usage: 2.5+ KB

# %%
numeric_columns = ["OPEN ","HIGH ","LOW ","PREV. CLOSE ","close ","ltp ","52W H ","52W L ","VOLUME ","No of trades "]

# %%
for i in numeric_columns:
    data[i]=data[i].str.replace(',','')
    data[i]=pd.to_numeric(data[i],errors='coerce')

# %%
data.drop(columns=['VALUE ','vwap ',"series ","PREV. CLOSE ","ltp ","52W H ","52W L ","No of trades "],inplace=True)

# %%
data['Date '] = pd.to_datetime(data['Date '])
data.set_index('Date ', inplace=True)

# %%
data
# Out:
#              OPEN    HIGH     LOW   close   VOLUME
# Date
# 2025-10-15  2971.0  2979.7  2951.0  2969.8  4282226
# 2025-10-14  3021.0  3027.2  2955.5  2960.3  3611416
# 2025-10-13  3027.0  3035.5  2998.2  3007.2  2866865
# 2025-10-10  3050.0  3070.0  3006.9  3028.3  8817365
# 2025-10-09  3034.0  3066.0  3020.0  3061.7  3211304
# 2025-10-08  2975.0  3043.0  2968.0  3027.2  4121889
# 2025-10-07  2995.0  3004.5  2955.5  2973.7  3062943
# 2025-10-06  2902.0  2993.6  2895.6  2988.4  2112774
# 2025-10-03  2924.0  2924.0  2891.1  2901.9  2899519
# 2025-10-01  2891.0  2924.8  2866.6  2914.2  1952902
# 2025-09-30  2911.0  2915.3  2885.1  2888.4  2253458
# 2025-09-29  2916.0  2929.3  2894.0  2896.1  3110035
# 2025-09-26  2941.0  2954.8  2891.3  2899.1  3934636
# 2025-09-25  3022.0  3029.6  2951.0  2957.4  4974361
# 2025-09-24  3050.0  3057.0  3033.0  3035.4  1625714
# 2025-09-23  3070.0  3080.7  3052.0  3062.4  3177741
# 2025-09-22  3095.0  3106.9  3065.0  3073.8  3634901
# 2025-09-19  3170.0  3180.5  3144.0  3169.2  4901694
# 2025-09-18  3185.0  3203.0  3161.4  3176.7  2633138
# 2025-09-17  3152.0  3182.4  3142.4  3172.8  2418271
# 2025-09-16  3128.0  3150.0  3109.1  3145.7  2573429
# 2025-09-15  3134.0  3134.0  3096.0  3111.9  1732539

# %% [raw]
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume'
#  ["OPEN ","HIGH ","LOW ","PREV. CLOSE ","ltp ","52W H ","52W L ","VOLUME ","No of trades "]

# %%
data = data.rename(columns={"Date ":"Date","OPEN ":"Open","HIGH ":'High',"LOW ":'Low','close ':"Close","VOLUME ":'Volume'})

# %%
data["Close"]
# Out:
# Date
# 2025-10-15    2969.8
# 2025-10-14    2960.3
# 2025-10-13    3007.2
# 2025-10-10    3028.3
# 2025-10-09    3061.7
# 2025-10-08    3027.2
# 2025-10-07    2973.7
# 2025-10-06    2988.4
# 2025-10-03    2901.9
# 2025-10-01    2914.2
# 2025-09-30    2888.4
# 2025-09-29    2896.1
# 2025-09-26    2899.1
# 2025-09-25    2957.4
# 2025-09-24    3035.4
# 2025-09-23    3062.4
# 2025-09-22    3073.8
# 2025-09-19    3169.2
# 2025-09-18    3176.7
# 2025-09-17    3172.8
# 2025-09-16    3145.7
# 2025-09-15    3111.9
# Name: Close, dtype: float64

# %%
X1=data.drop(columns ="Close")
value = scalerx.transform(X1)
value = np.reshape(value, (value.shape[0], 1, value.shape[1]))
predict1 = best_model.predict(value)
predict1 = np.array(predict1).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
y1 = predict1.reshape(-1, 1)
y1 = scalery.inverse_transform(y1)

# %%
y1
# Out:
# array([[2976.6082],
#        [3000.9133],
#        [3027.039 ],
#        [3033.5186],
#        [3051.761 ],
#        [3016.4016],
#        [2991.7844],
#        [2970.0798],
#        [2920.721 ],
#        [2913.4924],
#        [2915.286 ],
#        [2925.2427],
#        [2935.399 ],
#        [2996.0537],
#        [3056.7676],
#        [3071.83  ],
#        [3088.5051],
#        [3157.593 ],
#        [3183.8755],
#        [3165.6172],
#        [3131.2847],
#        [3118.8494]], dtype=float32)

# %%
data
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2025-10-15  2971.0  2979.7  2951.0  2969.8  4282226
# 2025-10-14  3021.0  3027.2  2955.5  2960.3  3611416
# 2025-10-13  3027.0  3035.5  2998.2  3007.2  2866865
# 2025-10-10  3050.0  3070.0  3006.9  3028.3  8817365
# 2025-10-09  3034.0  3066.0  3020.0  3061.7  3211304
# 2025-10-08  2975.0  3043.0  2968.0  3027.2  4121889
# 2025-10-07  2995.0  3004.5  2955.5  2973.7  3062943
# 2025-10-06  2902.0  2993.6  2895.6  2988.4  2112774
# 2025-10-03  2924.0  2924.0  2891.1  2901.9  2899519
# 2025-10-01  2891.0  2924.8  2866.6  2914.2  1952902
# 2025-09-30  2911.0  2915.3  2885.1  2888.4  2253458
# 2025-09-29  2916.0  2929.3  2894.0  2896.1  3110035
# 2025-09-26  2941.0  2954.8  2891.3  2899.1  3934636
# 2025-09-25  3022.0  3029.6  2951.0  2957.4  4974361
# 2025-09-24  3050.0  3057.0  3033.0  3035.4  1625714
# 2025-09-23  3070.0  3080.7  3052.0  3062.4  3177741
# 2025-09-22  3095.0  3106.9  3065.0  3073.8  3634901
# 2025-09-19  3170.0  3180.5  3144.0  3169.2  4901694
# 2025-09-18  3185.0  3203.0  3161.4  3176.7  2633138
# 2025-09-17  3152.0  3182.4  3142.4  3172.8  2418271
# 2025-09-16  3128.0  3150.0  3109.1  3145.7  2573429
# 2025-09-15  3134.0  3134.0  3096.0  3111.9  1732539

# %%
y2=data["Close"].values.reshape(-1, 1)

# %%
y2
# Out:
# array([[2969.8],
#        [2960.3],
#        [3007.2],
#        [3028.3],
#        [3061.7],
#        [3027.2],
#        [2973.7],
#        [2988.4],
#        [2901.9],
#        [2914.2],
#        [2888.4],
#        [2896.1],
#        [2899.1],
#        [2957.4],
#        [3035.4],
#        [3062.4],
#        [3073.8],
#        [3169.2],
#        [3176.7],
#        [3172.8],
#        [3145.7],
#        [3111.9]])

# %%
r2 = r2_score(y1, y2)

print(f" r2 : {r2:.4f}")
# Out:
#  r2 : 0.9407

# %%
plt.figure(figsize=(10,4))
plt.plot(y2,label="acutual value",linewidth=2)
plt.plot(y1,label="predicted value",linewidth=2)
plt.title("Actualvs prediction value of one month",fontsize=22)
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
